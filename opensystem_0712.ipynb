# %%
using IonSim
using QuantumOptics
using PyPlot

function plot_wigner(final_state)
    rho_motional = ptrace(final_state, 1)

b_fock = FockBasis(20)
rho_fock = DenseOperator(b_fock, rho_motional.data)

x_vec = -4.0:0.1:4.0
p_vec = -4.0:0.1:4.0

W = wigner(rho_fock, x_vec, p_vec)

fig = figure(figsize=(8, 6))
PyPlot.pcolormesh(x_vec, p_vec, W, cmap="RdBu_r", vmin=-0.1, vmax=0.3, shading="nearest")
PyPlot.colorbar(label="Wigner Function W(x, p)")

# Add a marker where the vacuum state (0,0) originally was
PyPlot.plot([0], [0], "w+", markersize=15, markeredgewidth=2, label="Original Vacuum |0>")

PyPlot.xlabel("Position (x)")
PyPlot.ylabel("Momentum (p)")
PyPlot.title("Displaced Motional State")
PyPlot.legend()
PyPlot.grid(color="white", alpha=0.2)

# Display the figure safely in Jupyter (removed show() to prevent the device warning)
display(fig)
end


function SDF_apply_with_alpha(angle = 0, time = 50.0, cat_state = false, initial_state = nothing)

    red_angle = (π - 2*angle ) /2
    blue_angle = red_angle + 2 *angle

    if (cat_state)
        println("Preparing cat state superposition...")
        red_angle = -angle
        blue_angle = angle
    end
    trap_freq = 19e5 # 1 MHz trap frequency
    ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
    chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq),selectedmodes=(; z=[1]))

    mode_z = zmodes(chain)[1] # Get the first (and only) Z-mode of the chain
    mode_z.N = 20
    mode_z.shape = [21]

   k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ

    laser_intensity = 1e6 # Adjust this to push the ion faster/slower
    B_field = 1e-13
    trap = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)
    transition_λ = transitionwavelength(ion, ("g", "e"), trap)

    L_red = Laser(Δ = -trap_freq, ϕ=red_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    L_blue = Laser(Δ = trap_freq, ϕ=blue_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])

    mode = zmodes(trap)[1]
    println(mode)

    ψ_ion = normalize(ion["g"] -  ion["e"])

    
    ψ_mode = fockstate(mode, 0)
    ψ_initial = ψ_ion ⊗ ψ_mode

    if (initial_state != nothing)
        println("Using provided initial state...")
        ψ_initial = initial_state
    end

    h = hamiltonian(trap, timescale=1e-6, rwa_cutoff=Inf)
    tspan = 0:0.5:time 
    println("Simulating bichromatic displacement...")
    tout, sol = timeevolution.schroedinger_dynamic(tspan, ψ_initial, h)

    final_state = sol[end]

    # ---------------------------------------------------------
# 1. Fundamental Physics Constants
# ---------------------------------------------------------
 hbar = 1.0545718e-34       # Reduced Planck constant (J*s)
 amu = 1.66053906e-27       # Atomic mass unit (kg)
 m_Ca40 = 39.96259 * amu    # Mass of Calcium-40 ion (kg)
 c = 2.99792458e8           # Speed of light (m/s)

# ---------------------------------------------------------
# 2. Your Simulated Experiment Parameters
# ---------------------------------------------------------     
wavelength = transition_λ             # Quadrupole transition wavelength (m)
tspan_end = time * 1e-6              # Total laser interaction time (s)
# ---------------------------------------------------------
# 3. Step-by-Step Calculation
# ---------------------------------------------------------

println("--- VERIFYING DISPLACEMENT PARAMETERS ---")

# Step A: Zero-Point Fluctuation (z_zpf)
# z_zpf = sqrt( ħ / (2 * m * ω_trap) )
omega_trap = 2 * π * trap_freq
z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
println("Zero-Point Fluctuation (z_zpf) : ", round(z_zpf * 1e9, digits=4), " nm")

# Step B: Wavevector Z-Projection (k_z)
# Your vector: k_vec = (x̂ + ẑ) / √2 
# Therefore, projection onto Z is 1/√2
k_total = 2 * π / wavelength
k_z = k_total / sqrt(2)
println("Z-Projected Wavevector (k_z)   : ", round(k_z, digits=2), " m⁻¹")

# Step C: Lamb-Dicke Parameter (η)
# η = k_z * z_zpf
eta = k_z * z_zpf
println("Lamb-Dicke Parameter (η)       : ", round(eta, digits=4))

# Step D: Effective Rabi Frequency (Ω_eff)
# The geometric coupling factor for a Δm=0 quadrupole transition using your 
# specific k_vec and ϵ_vec vectors results in a scaling reduction of 1/4.
# geometric_factor = 1.0 / 4.0
geometric_factor = 1.0 / ( sqrt(3)) 

# STRETCHED STATE: The CG coefficient is exactly 1.0! 
cg_factor = 1.0 # The Clebsch-Gordan factor for Δm=0 in Ca40

# The true effective Rabi frequency acting on the ion's orbitals
Omega_eff = laser_intensity * geometric_factor * cg_factor
println("Effective Rabi Freq (Ω_eff)    : ", Omega_eff, " rad/s")

# Step E: Displacement Magnitude (|α|)
# |α| = 1/2 * η * Ω_eff * t 
alpha_mag = 0.5 * eta * Omega_eff * tspan_end 

println("-----------------------------------------")
println("FINAL DISPLACEMENT MAGNITUDE (|α| = 0.5 * η * Ω_eff * t) : ", round(alpha_mag, digits=3))
println("-----------------------------------------")
return final_state
end

trap_freq = 19e5 # 1.9 MHz trap frequency
    ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
    chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))

    mode_z = zmodes(chain)[1] # Get the first (and only) Z-mode of the chain
    mode_z.N = 20
    mode_z.shape = [21]

    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ

    laser_intensity = 1e6 # Fixed intensity
    B_field = 1e-13
    
    # Pre-build a trap just to grab the transition wavelength
    trap = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)
    transition_λ = transitionwavelength(ion, ("g", "e"), trap)
    mode = zmodes(trap)[1]
    println(mode)
    ψ_ion = normalize(ion["g"] - ion["e"])
    ψ_mode = fockstate(mode, 0)
    ψ_initial = ψ_ion ⊗ ψ_mode

    # 1. Grab the exact mode object used in the simulation (no generic FockBasis!)
sim_mode = zmodes(trap)[1]
a = 0.716 * im 

# 2. Build the displacement operator using the IonSim mode
# IonSim has a built-in displace() method specifically for VibrationalModes
D_motion = IonSim.displace(sim_mode, a)

# 3. Create a "Do Nothing" operator for the ion's spin
I_spin = identityoperator(ion["g"].basis)

 ψ_ion = normalize(ion["g"] -  ion["e"])

# 4. Combine them into a full system operator (Spin ⊗ Motion)
D_system = identityoperator(ψ_ion.basis) ⊗ D_motion

# 5. Apply the operator to the state (The bases now match perfectly!)
displaced_final_state = D_system * ψ_initial

println(displaced_final_state)

function SDF_apply_with_alpha(angle = 0, target_alpha = 0.716, cat_state = false, initial_state = nothing, fock_state_n = 0)

    red_angle = (π - 2*angle ) /2
    blue_angle = red_angle + 2 *angle

    if (cat_state)
        # println("Preparing cat state superposi/tion...")
        red_angle = -angle
        blue_angle = angle
    end
    
    trap_freq = 19e5 # 1.9 MHz trap frequency
    ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
    chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))

    mode_z = zmodes(chain)[1] # Get the first (and only) Z-mode of the chain
    mode_z.N = 20
    mode_z.shape = [21]

    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ

    laser_intensity = 1e4 # Fixed intensity
    B_field = 1e-13
    
    # Pre-build a trap just to grab the transition wavelength
    trap_pre = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_pre)

    # ---------------------------------------------------------
    # NEW: DYNAMIC TIME CALCULATION VIA WIGNER-ECKART ENGINE
    # ---------------------------------------------------------
    hbar = 1.0545718e-34       
    amu = 1.66053906e-27       
    m_Ca40 = 39.96259 * amu    
    c = 2.99792458e8           

    # 1. Calculate Lamb-Dicke Parameter (η) dynamically
    omega_trap = 2 * π * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * π / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    # 2. Hijack IonSim's internal matrix element calculator
    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    
    # Feed the dummy laser into the exact internal physics engine
    # (Note: Unexported internal functions need the module prefix 'IonSim.')
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * π
    # 3. Solve the displacemen formula backward to find exactly how long to leave the lasers on
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    target_time_us = target_time_s * 1e6
    # ---------------------------------------------------------

    # Now build the actual lasers and final chamber
    L_red = Laser(Δ = -trap_freq, ϕ=red_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=blue_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])

    mode = zmodes(trap)[1]
    # println(mode)

    ψ_ion = normalize(ion["g"] - ion["e"])
    ψ_mode = fockstate(mode, fock_state_n)
    ψ_initial = ψ_ion ⊗ ψ_mode

    if (initial_state != nothing)
        ψ_initial = initial_state
    end

    h = hamiltonian(trap, timescale=1e-6, rwa_cutoff=Inf)
    
    # Ensure our solver array steps exactly up to our calculated target time
    tspan_array = collect(0:0.5:target_time_us)
    if tspan_array[end] < target_time_us
        push!(tspan_array, target_time_us)
    end

    tout, sol = timeevolution.schroedinger_dynamic(tspan_array, ψ_initial, h)

    final_state = sol[end]
    
    return final_state
end

function protocol(initialstate = nothing, beta = 1, alpha = 0.5)

    beta_state = SDF_apply_with_alpha(0, beta, false, initialstate, 0)
    final_state = SDF_apply_with_alpha(pi/2, alpha, true, beta_state, 0)

    return final_state
end

using LinearAlgebra

function calculate_qcrb(state, state_perturbed, d_alpha::Float64; tol=1e-10)
    
    # 1. Promote pure states (Ket) to density matrices
    rho1 = isa(state, Ket) ? dm(state) : state
    rho2 = isa(state_perturbed, Ket) ? dm(state_perturbed) : state_perturbed
    
    # 2. Extract dense data
    rho_dense_data = dense(rho1).data
    rho_pert_dense_data = dense(rho2).data

    # 3. Finite difference derivative
    drho_data = (rho_pert_dense_data - rho_dense_data) / d_alpha
    
    # 4. Use Hermitian() to guarantee real eigenvalues and speed up diagonalization
    λ, V = LinearAlgebra.eigen(Hermitian(rho_dense_data))
    
    qfi = 0.0
    n = length(λ)
    
    for i in 1:n
        for j in 1:n
            if real(λ[i] + λ[j]) > tol
                # 5. Use @views to prevent memory allocation during column slicing
                @views v_i = V[:, i]
                @views v_j = V[:, j]
                
                drho_ij = dot(v_i, drho_data * v_j)
                qfi += 2 * (abs(drho_ij)^2) / real(λ[i] + λ[j])
            end
        end
    end
    
    qcrb = qfi > 0 ? 1.0 / qfi : Inf
    return qfi, qcrb
end
cutoff = 20
b = FockBasis(cutoff)
vac = fockstate(b, 0)

# 2. Define squeeze parameter z (z = r * exp(i * theta))
z = 0.5 * exp(1im * pi) 

# 3. Create the squeezed state by applying the squeeze operator to the vacuum
squeeze_op = squeeze(b, z)
squeezed_vac = squeeze_op * vac

state = ψ_ion ⊗ squeezed_vac

plot_wigner(state)
# Out:
# VibrationalMode(ν=1.9e6, axis=ẑ, N=20)
# Ket(dim=42)
#   basis: [⁴⁰Ca ⊗ VibrationalMode(ν=1.9e6, axis=ẑ, N=20)]
#      0.54722151763696 + 0.0im
#     -0.54722151763696 + 0.0im
#                   0.0 + 0.3918106066280634im
#                   0.0 - 0.3918106066280634im
#   -0.1983691868114632 + 0.0im
#    0.1983691868114632 + 0.0im
#                   0.0 - 0.08200240843764023im
#                   0.0 + 0.08200240843764023im
#    0.0293568622206752 + 0.0im
#   -0.0293568622206752 + 0.0im
#                   0.0 + 0.0094002121409144im
#                   0.0 - 0.0094002121409144im
#  -0.00274773630415258 + 0.0im
#   0.00274773630415258 + 0.0im
#                   0.0 - 0.00074359944018383im
#                   0.0 + 0.00074359944018383im
#    0.0001882379059773 + 0.0im
#   -0.0001882379059773 + 0.0im
#                   0.0 + 4.492611355992e-5im
#                   0.0 - 4.492611355992e-5im
#    -1.017212932124e-5 + 0.0im
#     1.017212932124e-5 + 0.0im
#                   0.0 - 2.19598087043e-6im
#                   0.0 + 2.19598087043e-6im
#       4.5389035251e-7 + 0.0im
#      -4.5389035251e-7 + 0.0im
#                   0.0 + 9.01347582e-8im
#                   0.0 - 9.01347582e-8im
#       -1.724810163e-8 + 0.0im
#        1.724810163e-8 + 0.0im
#                   0.0 - 3.18866353e-9im
#                   0.0 + 3.18866353e-9im
#         5.7077078e-10 + 0.0im
#        -5.7077078e-10 + 0.0im
#                   0.0 + 9.911747e-11im
#                   0.0 - 9.911747e-11im
#         -1.672753e-11 + 0.0im
#          1.672753e-11 + 0.0im
#                   0.0 - 2.74623e-12im
#                   0.0 + 2.74623e-12im
#            4.5019e-13 + 0.0im
#           -4.5019e-13 + 0.0im
# calculate_qcrb (generic function with 1 method)

# %%
angle = 0
 target_alpha = 0.716
 cat_state = false
 initial_state = nothing
 fock_state_n = 0
red_angle = (π - 2*angle ) /2
    blue_angle = red_angle + 2 *angle

    if (cat_state)
        # println("Preparing cat state superposi/tion...")
        red_angle = -angle
        blue_angle = angle
    end
    
    trap_freq = 19e5 # 1.9 MHz trap frequency
    ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
    chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))

    mode_z = zmodes(chain)[1] # Get the first (and only) Z-mode of the chain
    mode_z.N = 20
    mode_z.shape = [21]

    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ

    laser_intensity = 1e4 # Fixed intensity
    B_field = 1e-13
    
    # Pre-build a trap just to grab the transition wavelength
    trap_pre = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_pre)

    # ---------------------------------------------------------
    # NEW: DYNAMIC TIME CALCULATION VIA WIGNER-ECKART ENGINE
    # ---------------------------------------------------------
    hbar = 1.0545718e-34       
    amu = 1.66053906e-27       
    m_Ca40 = 39.96259 * amu    
    c = 2.99792458e8           

    # 1. Calculate Lamb-Dicke Parameter (η) dynamically
    omega_trap = 2 * π * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * π / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    # 2. Hijack IonSim's internal matrix element calculator
    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    
    # Feed the dummy laser into the exact internal physics engine
    # (Note: Unexported internal functions need the module prefix 'IonSim.')
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * π
    # 3. Solve the displacemen formula backward to find exactly how long to leave the lasers on
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    target_time_us = target_time_s * 1e6
    # ---------------------------------------------------------

    # Now build the actual lasers and final chamber
    L_red = Laser(Δ = -trap_freq, ϕ=red_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=blue_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])

    mode = zmodes(trap)[1]
    # println(mode)

    ψ_ion = normalize(ion["g"] - ion["e"])
    ψ_mode = fockstate(mode, fock_state_n)
    ψ_initial = ψ_ion ⊗ ψ_mode

    if (initial_state != nothing)
        ψ_initial = initial_state
    end

    h = hamiltonian(trap, timescale=1e-6, rwa_cutoff=Inf)
    
    # Ensure our solver array steps exactly up to our calculated target time
    tspan_array = collect(0:0.5:target_time_us)
    if tspan_array[end] < target_time_us
        push!(tspan_array, target_time_us)
    end

    tout, sol = timeevolution.schroedinger_dynamic(tspan_array, ψ_initial, h)

    final_state = sol[end]

    sim_mode = zmodes(trap)[1]
    
    # 1. Create a temporary standard FockBasis of the EXACT same dimension
    temp_fock_basis = FockBasis(sim_mode.N)
    
    # 2. Use QuantumOptics to calculate the complex squeeze matrix
    z = 0.5 * exp(1im * pi) 
    S_fock = squeeze(temp_fock_basis, z) 
    
    # 3. THE FIX: Wrap the raw matrix data back into the IonSim mode!
    squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
    
    # 4. Build the vacuum state directly on the IonSim mode
    vac = fockstate(sim_mode, 0)
    
    # 5. Apply the wrapped squeeze operator
    ψ_mode = squeeze_op * vac
    
    # 6. Tensor the spin and the mode together
    ψ_initial = ψ_ion ⊗ ψ_mode
    
    # NOW APPLY SIGNAL: The dimensions and types match perfectly!
    ψ_initial_perturbed = D_system * ψ_initial

    # ---------------------------------------------------------
# Define Lindblad Jump Operators for Anomalous Heating
# ---------------------------------------------------------
n_th = 100.0             # High thermal phonon occupancy for surface trap bath
gamma_0 = 1e-4           # Intrinsic coupling rate
gamma_plus = gamma_0 * n_th       # Anomalous heating rate (phonon gain)
gamma_minus = gamma_0 * (n_th + 1) # Cooling rate (phonon loss)

# Ladder operators for the motional mode
# FIX: explicitly build the FockBasis using the cutoff dimension N
b_motional = FockBasis(sim_mode.N) 
a_op = QuantumOptics.destroy(b_motional)
at_op = QuantumOptics.create(b_motional)

# Extend operators to the full bipartite system (Spin ⊗ Motion)
a_sys = I_spin ⊗ a_op
at_sys = I_spin ⊗ at_op

# Define jump operators (L_k)
J_heat = sqrt(gamma_plus) * at_sys
J_cool = sqrt(gamma_minus) * a_sys
J_ops = [J_cool, J_heat]
# Out:
# 2-element Vector{Operator{CompositeBasis{Vector{Int64}, Tuple{IonInstance{:Ca40}, FockBasis{Int64}}}, CompositeBasis{Vector{Int64}, Tuple{IonInstance{:Ca40}, FockBasis{Int64}}}, SparseArrays.SparseMatrixCSC{ComplexF64, Int64}}}:
#  Operator(dim=42x42)
#   basis: [⁴⁰Ca ⊗ Fock(cutoff=20)]
# ⎡⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎤
# ⎢⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⎥
# ⎣⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎦
#  Operator(dim=42x42)
#   basis: [⁴⁰Ca ⊗ Fock(cutoff=20)]
# ⎡⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎤
# ⎢⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⎥
# ⎣⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⠀⎦

# %%
# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"] - ion["e"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = 1000.0             
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    gamma_plus_us = (gamma_0 * n_th) * 1e-6       
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 0:1 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 0
        println("Simulating Ordinary Vacuum |0⟩...")
        ψ_mode = fockstate(sim_mode, 0)
        label_sim = "Simulated Vacuum |0⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 0)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |0⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 0)
decay_penalty_0 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_0_open = @. (exp(4 * alphas_theory^2) * decay_penalty_0) / (16 * alphas_theory^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 0)
suppression_factor = exp(-2 * r_squeeze)
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2 * suppression_factor)
qcrb_theory_sq_open = @. (exp(4 * alphas_theory^2 * suppression_factor) * decay_penalty_sq) / (16 * alphas_theory^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_0_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="lower right", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |0⟩...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.249
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.612
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.421
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.704
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.69
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.211
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 0.954
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.809
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.727
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.687
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.679
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 0.697
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 0.742
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 0.817
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 0.929
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 1.088
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 1.311
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 1.624
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 2.067
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 2.701
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 3.62
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 4.976
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 7.011
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 10.12
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 14.963
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 22.653
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 35.109
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 55.695
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 90.414
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 150.175
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 255.18
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 443.541
# Simulating Squeezed Vacuum (r = 0.5)...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.092
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.453
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.258
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.535
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.512
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.021
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 0.749
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.583
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.476
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.403
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.352
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 0.316
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 0.29
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 0.272
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 0.26
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 0.253
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 0.25
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 0.25
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 0.255
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 0.263
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 0.274
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 0.29
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 0.31
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 0.335
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 0.367
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 0.406
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 0.453
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 0.512
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 0.583
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 0.672
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 0.781
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 0.917
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"] - ion["e"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = 100000.0             
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    gamma_plus_us = (gamma_0 * n_th) * 1e-6       
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 0:1 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 0
        println("Simulating Ordinary Vacuum |0⟩...")
        ψ_mode = fockstate(sim_mode, 0)
        label_sim = "Simulated Vacuum |0⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 0)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |0⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 0)
decay_penalty_0 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_0_open = @. (exp(4 * alphas_theory^2) * decay_penalty_0) / (16 * alphas_theory^2 + 1e-15)

qcrb_theory_0_close = @. (exp(4 * alphas_theory^2)) / (16 * alphas_theory^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 0)
suppression_factor = exp(-2 * r_squeeze)
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2 * suppression_factor)
qcrb_theory_sq_open = @. (exp(4 * alphas_theory^2 * suppression_factor) * decay_penalty_sq) / (16 * alphas_theory^2 + 1e-15)

qcrb_theory_sq_close = @. (exp(4 * alphas_theory^2 * suppression_factor)) / (16 * alphas_theory^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_0_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open) n_th = 100000.0")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_0_close, "--", color="gray", linewidth=1.5, label="Theory Vacuum (Closed)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_close, ":", color="orange", linewidth=2, label="Theory Squeezed (Closed, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |0⟩...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.25
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.613
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.422
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.706
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.693
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.215
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 0.96
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.816
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.737
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.7
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.696
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 0.72
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 0.774
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 0.862
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 0.992
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 1.179
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 1.445
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 1.826
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 2.375
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 3.179
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 4.378
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 6.2
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 9.026
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 13.506
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 20.767
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 32.813
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 53.266
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 88.837
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 152.213
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 267.939
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 484.552
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 900.32
# Simulating Squeezed Vacuum (r = 0.5)...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.092
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.454
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.259
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.537
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.515
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.024
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 0.753
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.588
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.482
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.41
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.361
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 0.326
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 0.302
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 0.287
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 0.278
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 0.274
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 0.275
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 0.282
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 0.293
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 0.309
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 0.331
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 0.361
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 0.399
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 0.447
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 0.508
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 0.586
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 0.685
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 0.812
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 0.977
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 1.19
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 1.471
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 1.843
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"] - ion["e"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = 1000000.0             
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    gamma_plus_us = (gamma_0 * n_th) * 1e-6       
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 0:1 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 0
        println("Simulating Ordinary Vacuum |0⟩...")
        ψ_mode = fockstate(sim_mode, 0)
        label_sim = "Simulated Vacuum |0⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 0)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |0⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 0)
decay_penalty_0 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_0_open = @. (exp(4 * alphas_theory^2) * decay_penalty_0) / (16 * alphas_theory^2 + 1e-15)

qcrb_theory_0_close = @. (exp(4 * alphas_theory^2)) / (16 * alphas_theory^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 0)
suppression_factor = exp(-2 * r_squeeze)
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2 * suppression_factor)
qcrb_theory_sq_open = @. (exp(4 * alphas_theory^2 * suppression_factor) * decay_penalty_sq) / (16 * alphas_theory^2 + 1e-15)

qcrb_theory_sq_close = @. (exp(4 * alphas_theory^2 * suppression_factor)) / (16 * alphas_theory^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_0_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open) n_th = $n_th")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_0_close, "--", color="gray", linewidth=1.5, label="Theory Vacuum (Closed)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_close, ":", color="orange", linewidth=2, label="Theory Squeezed (Closed, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |0⟩...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.251
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.619
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.434
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.725
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.719
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.251
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 1.008
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.882
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.826
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.823
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.868
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 0.965
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 1.13
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 1.392
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 1.804
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 2.456
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 3.517
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 5.299
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 8.405
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 14.047
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 24.761
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 46.09
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 90.702
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 188.965
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 417.376
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 978.858
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 2441.553
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 6487.99
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 18400.867
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 55804.13
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 181323.683
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 632517.322
# Simulating Squeezed Vacuum (r = 0.5)...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.093
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.46
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.271
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.554
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.538
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.055
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 0.791
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.636
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.541
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.483
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.45
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 0.437
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 0.442
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 0.463
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 0.504
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 0.57
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 0.668
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 0.813
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 1.029
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 1.353
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 1.851
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 2.638
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 3.919
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 6.076
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 9.843
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 16.684
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 29.622
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 55.17
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 107.936
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 222.148
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 481.72
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 1102.33
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
n_th_set = 100000.0

# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"] - ion["e"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = n_th_set           
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    gamma_plus_us = (gamma_0 * n_th) * 1e-6       
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 1:2 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 1
        println("Simulating Ordinary Vacuum |1⟩...")
        ψ_mode = fockstate(sim_mode, 1)
        label_sim = "Simulated Vacuum |1⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 1)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |1⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 1)
decay_penalty_1 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_1_open = @. (exp(4 * alphas_theory^2) * decay_penalty_1) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

qcrb_theory_1_close = @. (exp(4 * alphas_theory^2)) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 1)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2 * suppression_factor)
qcrb_theory_sq_open = @. (exp(x_sq) * decay_penalty_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

qcrb_theory_sq_close = @. (exp(x_sq)) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open) n_th = $n_th_set")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_1_close, "--", color="gray", linewidth=1.5, label="Theory Vacuum (Closed)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_close, ":", color="orange", linewidth=2, label="Theory Squeezed (Closed, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |1⟩...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.748
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 18.129
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.985
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 3.355
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 2.491
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 2.274
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 2.519
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 3.487
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 6.755
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 28.517
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 508.551
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 11.453
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 3.295
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 1.579
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 0.966
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 0.689
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 0.549
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 0.476
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 0.443
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 0.439
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 0.459
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 0.504
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 0.579
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 0.695
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 0.869
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 1.128
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 1.521
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 2.127
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 3.079
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 4.613
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 7.148
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 11.45
# Simulating Squeezed Vacuum (r = 0.5)...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.275
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.639
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.451
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.738
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.731
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.262
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 1.02
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.896
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.848
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.861
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.941
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 1.116
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 1.46
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 2.187
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 4.051
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 11.528
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 179.157
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 40.77
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 6.466
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 2.527
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 1.358
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 0.865
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 0.616
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 0.474
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 0.388
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 0.333
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 0.299
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 0.278
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 0.267
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 0.264
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 0.268
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 0.28
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
n_th_set = 1000000.0

# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"] - ion["e"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = n_th_set           
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    gamma_plus_us = (gamma_0 * n_th) * 1e-6       
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 1:2 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 1
        println("Simulating Ordinary Vacuum |1⟩...")
        ψ_mode = fockstate(sim_mode, 1)
        label_sim = "Simulated Vacuum |1⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 1)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |1⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 1)
decay_penalty_1 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_1_open = @. (exp(4 * alphas_theory^2) * decay_penalty_1) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

qcrb_theory_1_close = @. (exp(4 * alphas_theory^2)) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 1)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2 * suppression_factor)
qcrb_theory_sq_open = @. (exp(x_sq) * decay_penalty_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

qcrb_theory_sq_close = @. (exp(x_sq)) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open) n_th = $n_th_set")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_1_close, "--", color="gray", linewidth=1.5, label="Theory Vacuum (Closed)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_close, ":", color="orange", linewidth=2, label="Theory Squeezed (Closed, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e7) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |1⟩...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.749
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 18.135
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.998
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 3.378
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 2.529
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 2.341
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 2.645
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 3.763
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 7.559
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 33.355
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 647.847
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 15.376
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 4.809
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 2.546
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 1.751
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 1.429
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 1.326
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 1.37
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 1.552
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 1.914
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 2.554
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 3.677
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 5.696
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 9.481
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 16.949
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 32.531
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 67.054
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 148.521
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 353.792
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 907.356
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 2508.714
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 7489.084
# Simulating Squeezed Vacuum (r = 0.5)...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.276
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.646
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.463
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.757
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.758
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.299
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 1.071
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.968
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.95
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 1.012
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 1.172
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 1.491
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 2.123
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 3.51
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 7.286
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 23.556
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 405.953
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 121.51
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 22.962
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 11.104
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 7.585
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 6.309
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 6.019
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 6.391
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 7.43
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 9.361
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 12.702
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 18.487
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 28.788
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 47.891
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 85.046
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 161.176
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
n_th_set = 1000000.0

# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"] - ion["e"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = n_th_set           
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    # gamma_plus_us = (gamma_0 * n_th) * 1e-6 
    gamma_plus_us = 0.0      
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 1:2 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 1
        println("Simulating Ordinary Vacuum |1⟩...")
        ψ_mode = fockstate(sim_mode, 1)
        label_sim = "Simulated Vacuum |1⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 1)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |1⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 1)
decay_penalty_1 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_1_open = @. (exp(4 * alphas_theory^2) * decay_penalty_1) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

qcrb_theory_1_close = @. (exp(4 * alphas_theory^2)) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 1)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2 * suppression_factor)
qcrb_theory_sq_open = @. (exp(x_sq) * decay_penalty_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

qcrb_theory_sq_close = @. (exp(x_sq)) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open) n_th = $n_th_set")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_1_close, "--", color="gray", linewidth=1.5, label="Theory Vacuum (Closed)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_close, ":", color="orange", linewidth=2, label="Theory Squeezed (Closed, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e7) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |1⟩...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.745
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 18.115
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.957
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 3.306
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 2.404
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 2.113
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 2.187
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 2.676
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 4.027
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 8.386
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 37.994
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 631.379
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 16.07
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 4.809
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 2.368
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 1.476
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 1.062
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 0.847
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 0.729
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 0.667
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 0.644
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 0.65
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 0.683
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 0.744
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 0.836
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 0.969
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 1.154
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 1.41
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 1.766
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 2.264
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 2.965
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 3.965
# Simulating Squeezed Vacuum (r = 0.5)...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.275
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.636
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.445
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.729
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.718
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.243
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 0.992
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.856
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.789
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.771
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.797
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 0.87
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 1.006
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 1.241
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 1.651
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 2.414
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 4.029
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 8.326
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 26.74
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 541.836
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 98.333
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 18.156
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 7.898
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 4.681
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 3.277
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 2.555
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 2.152
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 1.923
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 1.804
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 1.762
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 1.782
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 1.86
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
n_th_set = 100000.0

# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"] - ion["e"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = n_th_set           
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    # gamma_plus_us = (gamma_0 * n_th) * 1e-6 
    gamma_plus_us = 0.0      
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 1:2 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 1
        println("Simulating Ordinary Vacuum |1⟩...")
        ψ_mode = fockstate(sim_mode, 1)
        label_sim = "Simulated Vacuum |1⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 1)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |1⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 1)
decay_penalty_1 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_1_open = @. (exp(4 * alphas_theory^2) * decay_penalty_1) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

qcrb_theory_1_close = @. (exp(4 * alphas_theory^2)) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 1)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2 * suppression_factor)
qcrb_theory_sq_open = @. (exp(x_sq) * decay_penalty_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

qcrb_theory_sq_close = @. (exp(x_sq)) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open) n_th = $n_th_set")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_1_close, "--", color="gray", linewidth=1.5, label="Theory Vacuum (Closed)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_close, ":", color="orange", linewidth=2, label="Theory Squeezed (Closed, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e7) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |1⟩...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.747
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 18.127
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.981
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 3.348
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 2.478
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 2.25
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 2.468
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 3.36
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 6.283
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 23.672
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 1914.654
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 13.463
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 3.571
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 1.649
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 0.983
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 0.684
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 0.532
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 0.45
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 0.408
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 0.392
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 0.397
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 0.421
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 0.465
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 0.535
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 0.638
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 0.788
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 1.005
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 1.323
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 1.796
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 2.511
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 3.61
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 5.337
# Simulating Squeezed Vacuum (r = 0.5)...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.275
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.638
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.449
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.736
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.727
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.256
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 1.012
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.885
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.832
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.838
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.904
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 1.053
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 1.345
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 1.941
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 3.37
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 8.294
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 59.047
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 97.207
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 8.547
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 2.909
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 1.456
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 0.882
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 0.602
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 0.446
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 0.352
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 0.291
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 0.251
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 0.224
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 0.206
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 0.195
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 0.189
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 0.187
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
n_th_set = 1000000.0

# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"] - ion["e"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = n_th_set           
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    # gamma_plus_us = (gamma_0 * n_th) * 1e-6 
    gamma_plus_us = 0.0      
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 1:2 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 1
        println("Simulating Ordinary Vacuum |1⟩...")
        ψ_mode = fockstate(sim_mode, 1)
        label_sim = "Simulated Vacuum |1⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 1)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |1⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 1)
decay_penalty_1 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_1_open = @. (exp(4 * alphas_theory^2) * decay_penalty_1) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

qcrb_theory_1_close = @. (exp(4 * alphas_theory^2)) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 1)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_sq_open = @. (exp(x_sq) * decay_penalty_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

qcrb_theory_sq_close = @. (exp(x_sq)) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open) n_th = $n_th_set")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_1_close, "--", color="gray", linewidth=1.5, label="Theory Vacuum (Closed)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_close, ":", color="orange", linewidth=2, label="Theory Squeezed (Closed, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e7) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |1⟩...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.745
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 18.115
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.957
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 3.306
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 2.404
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 2.113
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 2.187
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 2.676
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 4.027
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 8.386
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 37.994
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 631.379
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 16.07
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 4.809
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 2.368
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 1.476
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 1.062
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 0.847
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 0.729
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 0.667
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 0.644
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 0.65
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 0.683
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 0.744
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 0.836
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 0.969
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 1.154
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 1.41
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 1.766
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 2.264
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 2.965
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 3.965
# Simulating Squeezed Vacuum (r = 0.5)...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.275
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.636
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.445
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.729
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.718
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.243
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 0.992
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.856
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.789
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 0.771
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 0.797
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 0.87
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 1.006
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 1.241
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 1.651
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 2.414
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 4.029
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 8.326
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 26.74
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 541.836
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 98.333
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 18.156
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 7.898
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 4.681
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 3.277
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 2.555
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 2.152
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 1.923
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 1.804
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 1.762
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 1.782
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 1.86
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
n_th_set = 1000000.0

# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"] - ion["e"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = n_th_set           
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    gamma_plus_us = (gamma_0 * n_th) * 1e-6 
    # gamma_plus_us = 0.0      
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 1:2 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 1
        println("Simulating Ordinary Vacuum |1⟩...")
        ψ_mode = fockstate(sim_mode, 1)
        label_sim = "Simulated Vacuum |1⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 1)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |1⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 1)
decay_penalty_1 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_1_open = @. (exp(4 * alphas_theory^2) * decay_penalty_1) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

qcrb_theory_1_close = @. (exp(4 * alphas_theory^2)) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 1)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_sq_open = @. (exp(x_sq) * decay_penalty_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

qcrb_theory_sq_close = @. (exp(x_sq)) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open) n_th = $n_th_set")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_1_close, "--", color="gray", linewidth=1.5, label="Theory Vacuum (Closed)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_close, ":", color="orange", linewidth=2, label="Theory Squeezed (Closed, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e7) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |1⟩...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.749
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 18.135
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.998
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 3.378
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 2.529
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 2.341
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 2.645
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 3.763
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 7.559
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 33.355
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 647.847
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 15.376
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 4.809
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 2.546
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 1.751
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 1.429
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 1.326
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 1.37
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 1.552
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 1.914
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 2.554
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 3.677
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 5.696
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 9.481
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 16.949
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 32.531
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 67.054
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 148.521
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 353.792
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 907.356
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 2508.714
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 7489.084
# Simulating Squeezed Vacuum (r = 0.5)...
# Target α: 0.01 (Lasers on for 0.7 μs), QCRB: 625.276
# Target α: 0.06 (Lasers on for 4.19 μs), QCRB: 17.646
# Target α: 0.11 (Lasers on for 7.68 μs), QCRB: 5.463
# Target α: 0.16 (Lasers on for 11.16 μs), QCRB: 2.757
# Target α: 0.21 (Lasers on for 14.65 μs), QCRB: 1.758
# Target α: 0.26 (Lasers on for 18.14 μs), QCRB: 1.299
# Target α: 0.31 (Lasers on for 21.63 μs), QCRB: 1.071
# Target α: 0.36 (Lasers on for 25.12 μs), QCRB: 0.968
# Target α: 0.41 (Lasers on for 28.61 μs), QCRB: 0.95
# Target α: 0.46 (Lasers on for 32.1 μs), QCRB: 1.012
# Target α: 0.51 (Lasers on for 35.59 μs), QCRB: 1.172
# Target α: 0.56 (Lasers on for 39.08 μs), QCRB: 1.491
# Target α: 0.61 (Lasers on for 42.57 μs), QCRB: 2.123
# Target α: 0.66 (Lasers on for 46.06 μs), QCRB: 3.51
# Target α: 0.71 (Lasers on for 49.54 μs), QCRB: 7.286
# Target α: 0.76 (Lasers on for 53.03 μs), QCRB: 23.556
# Target α: 0.81 (Lasers on for 56.52 μs), QCRB: 405.953
# Target α: 0.86 (Lasers on for 60.01 μs), QCRB: 121.51
# Target α: 0.91 (Lasers on for 63.5 μs), QCRB: 22.962
# Target α: 0.96 (Lasers on for 66.99 μs), QCRB: 11.104
# Target α: 1.01 (Lasers on for 70.48 μs), QCRB: 7.585
# Target α: 1.06 (Lasers on for 73.97 μs), QCRB: 6.309
# Target α: 1.11 (Lasers on for 77.46 μs), QCRB: 6.019
# Target α: 1.16 (Lasers on for 80.95 μs), QCRB: 6.391
# Target α: 1.21 (Lasers on for 84.44 μs), QCRB: 7.43
# Target α: 1.26 (Lasers on for 87.92 μs), QCRB: 9.361
# Target α: 1.31 (Lasers on for 91.41 μs), QCRB: 12.702
# Target α: 1.36 (Lasers on for 94.9 μs), QCRB: 18.487
# Target α: 1.41 (Lasers on for 98.39 μs), QCRB: 28.788
# Target α: 1.46 (Lasers on for 101.88 μs), QCRB: 47.891
# Target α: 1.51 (Lasers on for 105.37 μs), QCRB: 85.046
# Target α: 1.56 (Lasers on for 108.86 μs), QCRB: 161.176
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
n_th_set = 1000000.0

# =====================================================================
# 1. GLOBAL HARDWARE SETUP (Used for initial states & the protocol)
# =====================================================================
trap_freq = 19e5 
laser_intensity = 1e6
B_field = 1e-13

ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))
trap_base = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)

sim_mode = zmodes(trap_base)[1]
sim_mode.N = 40
sim_mode.shape = [41]

ψ_ion = normalize(ion["g"])
I_spin = identityoperator(ion["g"].basis)

# =====================================================================
# 2. THE ENCAPSULATED LINDBLAD PROTOCOL FUNCTION
# =====================================================================
function protocol_linbladian(rho_initial, target_alpha)
    # Hardware Geometry
    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_base)

    # Physics Constants for Wigner-Eckart dynamic time
    hbar = 1.0545718e-34
    amu = 1.66053906e-27
    m_Ca40 = 39.96259 * amu

    omega_trap = 2 * pi * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * pi / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * pi

    # 1. Solve the exact exposure time required for target_alpha
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    t_us = target_time_s * 1e6
    
    # 2. Anomalous Heating Rates
    n_th = n_th_set           
    gamma_0 = 1e-2           
    
    # CRITICAL: Scale per-second rates to per-microsecond rates for the solver
    gamma_plus_us = (gamma_0 * n_th) * 1e-6 
    # gamma_plus_us = 0.0      
    gamma_minus_us = (gamma_0 * (n_th + 1)) * 1e-6 
    Gamma_eff_us = (gamma_plus_us + gamma_minus_us) / 2

    # Handle t=0 edge case to prevent solver errors
    if target_alpha == 0.0
        return rho_initial, 0.0, eta, Omega_eff, Gamma_eff_us
    end

    # 3. Active Lasers for Schrödinger Cat State (SDF)
    angle = pi/2
    L_red = Laser(Δ = -trap_freq, ϕ=-angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=angle, I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap_active = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])
    H_SDF_active = hamiltonian(trap_active, timescale=1e-6, rwa_cutoff=3e5)

    # 4. Lindblad Jump Operators
    active_mode = zmodes(trap_active)[1]
    temp_fock_basis = FockBasis(active_mode.N) 
    
    a_op = DenseOperator(active_mode, active_mode, QuantumOptics.destroy(temp_fock_basis).data)
    at_op = DenseOperator(active_mode, active_mode, QuantumOptics.create(temp_fock_basis).data)

    a_sys = I_spin ⊗ a_op
    at_sys = I_spin ⊗ at_op

    J_cool = sqrt(gamma_minus_us) * a_sys
    J_heat = sqrt(gamma_plus_us) * at_sys
    J_ops = [J_cool, J_heat]
    J_ops_dag = dagger.(J_ops)

    # 5. Execute Solver
    function f_dyn(time_t, rho_state)
        return (H_SDF_active(time_t, rho_state), J_ops, J_ops_dag)
    end

    tout, rho_t = timeevolution.master_dynamic([0.0, t_us], rho_initial, f_dyn)
    
    return rho_t[end], t_us, eta, Omega_eff, Gamma_eff_us
end

# =====================================================================
# 3. MAIN SIMULATION LOOP (Driven by α)
# =====================================================================
alpha_max = 1.6
alpha_steps = 0.01:0.05:alpha_max 
states = 1:2 
r_squeeze = 0.5

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(alpha_steps))

# Placeholders for mapping the theory curve correctly
global_eta = 0.0
global_Omega_eff = 0.0
global_Gamma_eff = 0.0

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 1
        println("Simulating Ordinary Vacuum |1⟩...")
        ψ_mode = fockstate(sim_mode, 1)
        label_sim = "Simulated Vacuum |1⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        temp_fock_basis = FockBasis(sim_mode.N)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 1)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |1⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    rho_initial = dm(ψ_initial)
    
    for (j, target_alpha) in enumerate(alpha_steps)
        
        # 1. RUN THE MODULAR PROTOCOL
        rho_final, t_us, eta, Omega_eff, Gamma_eff = protocol_linbladian(rho_initial, target_alpha)
        
        # Capture hardware parameters to perfectly map the theory overlay later
        global_eta = eta
        global_Omega_eff = Omega_eff
        global_Gamma_eff = Gamma_eff

        # 2. Extract Visibility from Spin Coherence
        ancilla = ptrace(rho_final, 2) 
        coherence = abs(ancilla.data[1, 2])
        V_sim = 2.0 * coherence
        
        # 3. Calculate exact analytical limit
        qfi_sim = 16.0 * (target_alpha^2) * (V_sim^2)
        qcrb = 1.0 / (qfi_sim + 1e-15) 
        
        push!(qcrb_values, qcrb)
        qcrb_matrix[i, j] = qcrb
        
        println("Target α: ", round(target_alpha, digits=3), " (Lasers on for ", round(t_us, digits=2), " μs), QCRB: ", round(qcrb, digits=3))
    end
    
    # Plot this state's simulated data points
    PyPlot.plot(alpha_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# =====================================================================
# 4. ANALYTICAL THEORY OVERLAY
# =====================================================================
alphas_theory = range(0.01, stop=alpha_max, length=1000)

# Reconstruct the exact exposure time arrays using the hardware physics engine
t_theory_us = @. (2 * alphas_theory) / (global_eta * global_Omega_eff) * 1e6

# 1. Open System Theory for Ordinary Vacuum (r = 0, n = 1)
decay_penalty_1 = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_1_open = @. (exp(4 * alphas_theory^2) * decay_penalty_1) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

qcrb_theory_1_close = @. (exp(4 * alphas_theory^2)) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

# 2. Open System Theory for Squeezed Vacuum (r = r_squeeze, n = 1)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
decay_penalty_sq = @. exp(4 * global_Gamma_eff * t_theory_us * alphas_theory^2)
qcrb_theory_sq_open = @. (exp(x_sq) * decay_penalty_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

qcrb_theory_sq_close = @. (exp(x_sq)) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1_open, "--", color="black", linewidth=2, label="Theory Vacuum (Open) n_th = $n_th_set")
PyPlot.plot(alphas_theory, qcrb_theory_sq_open, ":", color="red", linewidth=2.5, label="Theory Squeezed (Open, r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_1_close, "--", color="gray", linewidth=1.5, label="Theory Vacuum (Closed)")
PyPlot.plot(alphas_theory, qcrb_theory_sq_close, ":", color="orange", linewidth=2, label="Theory Squeezed (Closed, r=$r_squeeze)")

# =====================================================================
# 5. PLOT FORMATTING
# =====================================================================
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e7) 

PyPlot.xlabel("Wavepacket Displacement [α]", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Open-System Squeezed Metrology", fontsize=14)

PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
