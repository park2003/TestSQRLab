# %%
using IonSim
using QuantumOptics
using PyPlot

function plot_wigner(final_state)
    rho_motional = ptrace(final_state, 1)

b_fock = FockBasis(20)
rho_fock = DenseOperator(b_fock, rho_motional.data)

x_vec = -4.0:0.1:4.0
p_vec = -4.0:0.1:4.0

W = wigner(rho_fock, x_vec, p_vec)

fig = figure(figsize=(8, 6))
PyPlot.pcolormesh(x_vec, p_vec, W, cmap="RdBu_r", vmin=-0.1, vmax=0.3, shading="nearest")
PyPlot.colorbar(label="Wigner Function W(x, p)")

# Add a marker where the vacuum state (0,0) originally was
PyPlot.plot([0], [0], "w+", markersize=15, markeredgewidth=2, label="Original Vacuum |0>")

PyPlot.xlabel("Position (x)")
PyPlot.ylabel("Momentum (p)")
PyPlot.title("Displaced Motional State")
PyPlot.legend()
PyPlot.grid(color="white", alpha=0.2)

# Display the figure safely in Jupyter (removed show() to prevent the device warning)
display(fig)
end


function SDF_apply_with_alpha(angle = 0, time = 50.0, cat_state = false, initial_state = nothing)

    red_angle = (π - 2*angle ) /2
    blue_angle = red_angle + 2 *angle

    if (cat_state)
        println("Preparing cat state superposition...")
        red_angle = -angle
        blue_angle = angle
    end
    trap_freq = 19e5 # 1 MHz trap frequency
    ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
    chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq),selectedmodes=(; z=[1]))

    mode_z = zmodes(chain)[1] # Get the first (and only) Z-mode of the chain
    mode_z.N = 20
    mode_z.shape = [21]

   k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ

    laser_intensity = 1e6 # Adjust this to push the ion faster/slower
    B_field = 1e-13
    trap = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)
    transition_λ = transitionwavelength(ion, ("g", "e"), trap)

    L_red = Laser(Δ = -trap_freq, ϕ=red_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    L_blue = Laser(Δ = trap_freq, ϕ=blue_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])

    mode = zmodes(trap)[1]
    println(mode)

    ψ_ion = normalize(ion["g"] -  ion["e"])

    
    ψ_mode = fockstate(mode, 0)
    ψ_initial = ψ_ion ⊗ ψ_mode

    if (initial_state != nothing)
        println("Using provided initial state...")
        ψ_initial = initial_state
    end

    h = hamiltonian(trap, timescale=1e-6, rwa_cutoff=Inf)
    tspan = 0:0.5:time 
    println("Simulating bichromatic displacement...")
    tout, sol = timeevolution.schroedinger_dynamic(tspan, ψ_initial, h)

    final_state = sol[end]

    # ---------------------------------------------------------
# 1. Fundamental Physics Constants
# ---------------------------------------------------------
 hbar = 1.0545718e-34       # Reduced Planck constant (J*s)
 amu = 1.66053906e-27       # Atomic mass unit (kg)
 m_Ca40 = 39.96259 * amu    # Mass of Calcium-40 ion (kg)
 c = 2.99792458e8           # Speed of light (m/s)

# ---------------------------------------------------------
# 2. Your Simulated Experiment Parameters
# ---------------------------------------------------------     
wavelength = transition_λ             # Quadrupole transition wavelength (m)
tspan_end = time * 1e-6              # Total laser interaction time (s)
# ---------------------------------------------------------
# 3. Step-by-Step Calculation
# ---------------------------------------------------------

println("--- VERIFYING DISPLACEMENT PARAMETERS ---")

# Step A: Zero-Point Fluctuation (z_zpf)
# z_zpf = sqrt( ħ / (2 * m * ω_trap) )
omega_trap = 2 * π * trap_freq
z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
println("Zero-Point Fluctuation (z_zpf) : ", round(z_zpf * 1e9, digits=4), " nm")

# Step B: Wavevector Z-Projection (k_z)
# Your vector: k_vec = (x̂ + ẑ) / √2 
# Therefore, projection onto Z is 1/√2
k_total = 2 * π / wavelength
k_z = k_total / sqrt(2)
println("Z-Projected Wavevector (k_z)   : ", round(k_z, digits=2), " m⁻¹")

# Step C: Lamb-Dicke Parameter (η)
# η = k_z * z_zpf
eta = k_z * z_zpf
println("Lamb-Dicke Parameter (η)       : ", round(eta, digits=4))

# Step D: Effective Rabi Frequency (Ω_eff)
# The geometric coupling factor for a Δm=0 quadrupole transition using your 
# specific k_vec and ϵ_vec vectors results in a scaling reduction of 1/4.
# geometric_factor = 1.0 / 4.0
geometric_factor = 1.0 / ( sqrt(3)) 

# STRETCHED STATE: The CG coefficient is exactly 1.0! 
cg_factor = 1.0 # The Clebsch-Gordan factor for Δm=0 in Ca40

# The true effective Rabi frequency acting on the ion's orbitals
Omega_eff = laser_intensity * geometric_factor * cg_factor
println("Effective Rabi Freq (Ω_eff)    : ", Omega_eff, " rad/s")

# Step E: Displacement Magnitude (|α|)
# |α| = 1/2 * η * Ω_eff * t 
alpha_mag = 0.5 * eta * Omega_eff * tspan_end 

println("-----------------------------------------")
println("FINAL DISPLACEMENT MAGNITUDE (|α| = 0.5 * η * Ω_eff * t) : ", round(alpha_mag, digits=3))
println("-----------------------------------------")
return final_state
end

trap_freq = 19e5 # 1.9 MHz trap frequency
    ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
    chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))

    mode_z = zmodes(chain)[1] # Get the first (and only) Z-mode of the chain
    mode_z.N = 20
    mode_z.shape = [21]

    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ

    laser_intensity = 1e6 # Fixed intensity
    B_field = 1e-13
    
    # Pre-build a trap just to grab the transition wavelength
    trap = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)
    transition_λ = transitionwavelength(ion, ("g", "e"), trap)
    mode = zmodes(trap)[1]
    println(mode)
    ψ_ion = normalize(ion["g"] - ion["e"])
    ψ_mode = fockstate(mode, 0)
    ψ_initial = ψ_ion ⊗ ψ_mode

    # 1. Grab the exact mode object used in the simulation (no generic FockBasis!)
sim_mode = zmodes(trap)[1]
a = 0.716 * im 

# 2. Build the displacement operator using the IonSim mode
# IonSim has a built-in displace() method specifically for VibrationalModes
D_motion = IonSim.displace(sim_mode, a)

# 3. Create a "Do Nothing" operator for the ion's spin
I_spin = identityoperator(ion["g"].basis)

 ψ_ion = normalize(ion["g"] -  ion["e"])

# 4. Combine them into a full system operator (Spin ⊗ Motion)
D_system = identityoperator(ψ_ion.basis) ⊗ D_motion

# 5. Apply the operator to the state (The bases now match perfectly!)
displaced_final_state = D_system * ψ_initial

println(displaced_final_state)

function SDF_apply_with_alpha(angle = 0, target_alpha = 0.716, cat_state = false, initial_state = nothing, fock_state_n = 0)

    red_angle = (π - 2*angle ) /2
    blue_angle = red_angle + 2 *angle

    if (cat_state)
        # println("Preparing cat state superposi/tion...")
        red_angle = -angle
        blue_angle = angle
    end
    
    trap_freq = 19e5 # 1.9 MHz trap frequency
    ion = Ca40([("S1/2", -1/2, "g"), ("D5/2", -5/2, "e")])
    chain = LinearChain(ions=[ion], comfrequencies=(x=3e6, y=3e6, z=trap_freq), selectedmodes=(; z=[1]))

    mode_z = zmodes(chain)[1] # Get the first (and only) Z-mode of the chain
    mode_z.N = 20
    mode_z.shape = [21]

    k_vec = (x̂ + ẑ) / √2
    ϵ_vec = ŷ

    laser_intensity = 1e4 # Fixed intensity
    B_field = 1e-13
    
    # Pre-build a trap just to grab the transition wavelength
    trap_pre = Chamber(iontrap=chain, B=B_field, Bhat=ẑ)
    transition_λ = transitionwavelength(ion, ("g", "e"), trap_pre)

    # ---------------------------------------------------------
    # NEW: DYNAMIC TIME CALCULATION VIA WIGNER-ECKART ENGINE
    # ---------------------------------------------------------
    hbar = 1.0545718e-34       
    amu = 1.66053906e-27       
    m_Ca40 = 39.96259 * amu    
    c = 2.99792458e8           

    # 1. Calculate Lamb-Dicke Parameter (η) dynamically
    omega_trap = 2 * π * trap_freq
    z_zpf = sqrt(hbar / (2 * m_Ca40 * omega_trap))
    k_total = 2 * π / transition_λ
    k_z = k_total / sqrt(2)
    eta = k_z * z_zpf

    # 2. Hijack IonSim's internal matrix element calculator
    dummy_laser = Laser(I=laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    Bhat_tuple = (; x=0.0, y=0.0, z=1.0)
    
    # Feed the dummy laser into the exact internal physics engine
    # (Note: Unexported internal functions need the module prefix 'IonSim.')
    Omega_eff_Hz = IonSim.matrixelement(ion, ("g", "e"), laser_intensity, polarization(dummy_laser), wavevector(dummy_laser), Bhat_tuple)
    Omega_eff = Omega_eff_Hz * 2 * π
    # 3. Solve the displacemen formula backward to find exactly how long to leave the lasers on
    target_time_s = (2 * target_alpha) / (eta * Omega_eff)
    target_time_us = target_time_s * 1e6
    # ---------------------------------------------------------

    # Now build the actual lasers and final chamber
    L_red = Laser(Δ = -trap_freq, ϕ=red_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)
    L_blue = Laser(Δ = trap_freq, ϕ=blue_angle, I = laser_intensity, k=k_vec, ϵ=ϵ_vec, λ=transition_λ)

    trap = Chamber(iontrap=chain, B=B_field, Bhat=ẑ, lasers=[L_red, L_blue])

    mode = zmodes(trap)[1]
    # println(mode)

    ψ_ion = normalize(ion["g"] - ion["e"])
    ψ_mode = fockstate(mode, fock_state_n)
    ψ_initial = ψ_ion ⊗ ψ_mode

    if (initial_state != nothing)
        ψ_initial = initial_state
    end

    h = hamiltonian(trap, timescale=1e-6, rwa_cutoff=Inf)
    
    # Ensure our solver array steps exactly up to our calculated target time
    tspan_array = collect(0:0.5:target_time_us)
    if tspan_array[end] < target_time_us
        push!(tspan_array, target_time_us)
    end

    tout, sol = timeevolution.schroedinger_dynamic(tspan_array, ψ_initial, h)

    final_state = sol[end]
    
    return final_state
end

function protocol(initialstate = nothing, beta = 1, alpha = 0.5)

    beta_state = SDF_apply_with_alpha(0, beta, false, initialstate, 0)
    final_state = SDF_apply_with_alpha(pi/2, alpha, true, beta_state, 0)

    return final_state
end

using LinearAlgebra

function calculate_qcrb(state, state_perturbed, d_alpha::Float64; tol=1e-10)
    
    # 1. Promote pure states (Ket) to density matrices
    rho1 = isa(state, Ket) ? dm(state) : state
    rho2 = isa(state_perturbed, Ket) ? dm(state_perturbed) : state_perturbed
    
    # 2. Extract dense data
    rho_dense_data = dense(rho1).data
    rho_pert_dense_data = dense(rho2).data

    # 3. Finite difference derivative
    drho_data = (rho_pert_dense_data - rho_dense_data) / d_alpha
    
    # 4. Use Hermitian() to guarantee real eigenvalues and speed up diagonalization
    λ, V = LinearAlgebra.eigen(Hermitian(rho_dense_data))
    
    qfi = 0.0
    n = length(λ)
    
    for i in 1:n
        for j in 1:n
            if real(λ[i] + λ[j]) > tol
                # 5. Use @views to prevent memory allocation during column slicing
                @views v_i = V[:, i]
                @views v_j = V[:, j]
                
                drho_ij = dot(v_i, drho_data * v_j)
                qfi += 2 * (abs(drho_ij)^2) / real(λ[i] + λ[j])
            end
        end
    end
    
    qcrb = qfi > 0 ? 1.0 / qfi : Inf
    return qfi, qcrb
end
# Out:
# VibrationalMode(ν=1.9e6, axis=ẑ, N=20)
# Ket(dim=42)
#   basis: [⁴⁰Ca ⊗ VibrationalMode(ν=1.9e6, axis=ẑ, N=20)]
#      0.54722151763696 + 0.0im
#     -0.54722151763696 + 0.0im
#                   0.0 + 0.3918106066280634im
#                   0.0 - 0.3918106066280634im
#   -0.1983691868114632 + 0.0im
#    0.1983691868114632 + 0.0im
#                   0.0 - 0.08200240843764023im
#                   0.0 + 0.08200240843764023im
#    0.0293568622206752 + 0.0im
#   -0.0293568622206752 + 0.0im
#                   0.0 + 0.0094002121409144im
#                   0.0 - 0.0094002121409144im
#  -0.00274773630415258 + 0.0im
#   0.00274773630415258 + 0.0im
#                   0.0 - 0.00074359944018383im
#                   0.0 + 0.00074359944018383im
#    0.0001882379059773 + 0.0im
#   -0.0001882379059773 + 0.0im
#                   0.0 + 4.492611355992e-5im
#                   0.0 - 4.492611355992e-5im
#    -1.017212932124e-5 + 0.0im
#     1.017212932124e-5 + 0.0im
#                   0.0 - 2.19598087043e-6im
#                   0.0 + 2.19598087043e-6im
#       4.5389035251e-7 + 0.0im
#      -4.5389035251e-7 + 0.0im
#                   0.0 + 9.01347582e-8im
#                   0.0 - 9.01347582e-8im
#       -1.724810163e-8 + 0.0im
#        1.724810163e-8 + 0.0im
#                   0.0 - 3.18866353e-9im
#                   0.0 + 3.18866353e-9im
#         5.7077078e-10 + 0.0im
#        -5.7077078e-10 + 0.0im
#                   0.0 + 9.911747e-11im
#                   0.0 - 9.911747e-11im
#         -1.672753e-11 + 0.0im
#          1.672753e-11 + 0.0im
#                   0.0 - 2.74623e-12im
#                   0.0 + 2.74623e-12im
#            4.5019e-13 + 0.0im
#           -4.5019e-13 + 0.0im
# calculate_qcrb (generic function with 1 method)

# %%
cutoff = 20
b = FockBasis(cutoff)
vac = fockstate(b, 0)

# 2. Define squeeze parameter z (z = r * exp(i * theta))
z = 0.5 * exp(1im * pi) 

# 3. Create the squeezed state by applying the squeeze operator to the vacuum
squeeze_op = squeeze(b, z)
squeezed_vac = squeeze_op * vac

state = ψ_ion ⊗ squeezed_vac

plot_wigner(state)
# Out:
# Figure(PyObject <Figure size 800x600 with 2 Axes>)

# %%
# ---------------------------------------------------------
# QCRB Simulation Loop: Ancilla Qubit Readout (Corrected)
# ---------------------------------------------------------
t_max = 1.6
time_steps = 0.01:0.05:t_max 
states = 0:1 
ψ_ion = normalize(ion["g"] - ion["e"])
# Infinitesimal mathematical signal
d_alpha = 0.01

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(time_steps))

# Pre-build the signal operator once to save loop time
sim_mode = zmodes(trap)[1]
D_signal = IonSim.displace(sim_mode, im* d_alpha)
I_spin = identityoperator(ion["g"].basis)
D_system = I_spin ⊗ D_signal


for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if (n == 0)
        ψ_mode = fockstate(mode, 0)
    else
       temp_fock_basis = FockBasis(sim_mode.N)
        z = 0.5 * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 0)
        ψ_mode = squeeze_op * vac
    end
    ψ_initial = ψ_ion ⊗ ψ_mode
    
    # APPLY SIGNAL FIRST: Create the perturbed initial state
    ψ_initial_perturbed = D_system * ψ_initial
    
    println("Simulating Fock State |", n, "⟩ (Ancilla Readout)...")
    
    for (j, t) in enumerate(time_steps)
        # 1. Base Trajectory (No Signal)
        sol1 = protocol(ψ_initial, 1, t)
        ancilla_base = ptrace(sol1, 2) 

        finalstate = sol1
        
        # 2. Perturbed Trajectory (Signal happened before SDF readout)
        sol2 = protocol(ψ_initial_perturbed, 1, t)
        ancilla_perturbed = ptrace(sol2, 2)

        finalstate_perturbed = sol2

        # 3. Calculate true Ancilla QCRB
        qfi, qcrb = calculate_qcrb(ancilla_base, ancilla_perturbed, d_alpha)
        push!(qcrb_values, qcrb)
        
        qcrb_matrix[i, j] = qcrb
        println("Beta: ", round(t, digits=2), " μs, Fock |", n, "⟩, QCRB: ", qcrb)
    end

    PyPlot.plot(time_steps, qcrb_values, label="Fock State |$n⟩", linewidth=2.5, linestyle="-")
end

PyPlot.yscale("log")
# We can now confidently constrain the Y-axis to relevant physical limits

PyPlot.xlabel("Laser Exposure Time [Displacement α] (μs)", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Experimental Metrological Limits via Ancilla Readout", fontsize=14)
PyPlot.legend(loc="upper right", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Fock State |0⟩ (Ancilla Readout)...
# Beta: 0.01 μs, Fock |0⟩, QCRB: 631.2804651034652
# Beta: 0.06 μs, Fock |0⟩, QCRB: 17.853317960472243
# Beta: 0.11 μs, Fock |0⟩, QCRB: 5.480696619445355
# Beta: 0.16 μs, Fock |0⟩, QCRB: 2.7366460232628054
# Beta: 0.21 μs, Fock |0⟩, QCRB: 1.7067531376906622
# Beta: 0.26 μs, Fock |0⟩, QCRB: 1.2222911786859958
# Beta: 0.31 μs, Fock |0⟩, QCRB: 0.9620008158741804
# Beta: 0.36 μs, Fock |0⟩, QCRB: 0.8140242674113498
# Beta: 0.41 μs, Fock |0⟩, QCRB: 0.730716001992581
# Beta: 0.46 μs, Fock |0⟩, QCRB: 0.689116207868187
# Beta: 0.51 μs, Fock |0⟩, QCRB: 0.6789473672891637
# Beta: 0.56 μs, Fock |0⟩, QCRB: 0.695545159072008
# Beta: 0.61 μs, Fock |0⟩, QCRB: 0.7385048533548646
# Beta: 0.66 μs, Fock |0⟩, QCRB: 0.8106020910282363
# Beta: 0.71 μs, Fock |0⟩, QCRB: 0.9183011534542179
# Beta: 0.76 μs, Fock |0⟩, QCRB: 1.071108067235525
# Beta: 0.81 μs, Fock |0⟩, QCRB: 1.2863343910699536
# Beta: 0.86 μs, Fock |0⟩, QCRB: 1.586894629072432
# Beta: 0.91 μs, Fock |0⟩, QCRB: 2.011107225018214
# Beta: 0.96 μs, Fock |0⟩, QCRB: 2.6163705142388256
# Beta: 1.01 μs, Fock |0⟩, QCRB: 3.4879377979552673
# Beta: 1.06 μs, Fock |0⟩, QCRB: 4.772931679569251
# Beta: 1.11 μs, Fock |0⟩, QCRB: 6.683163802659482
# Beta: 1.16 μs, Fock |0⟩, QCRB: 9.596310642984157
# Beta: 1.21 μs, Fock |0⟩, QCRB: 14.102597773148151
# Beta: 1.26 μs, Fock |0⟩, QCRB: 21.20713981083698
# Beta: 1.31 μs, Fock |0⟩, QCRB: 32.680490350766675
# Beta: 1.36 μs, Fock |0⟩, QCRB: 51.43305148401149
# Beta: 1.41 μs, Fock |0⟩, QCRB: 82.97179047311695
# Beta: 1.46 μs, Fock |0⟩, QCRB: 136.7046244690053
# Beta: 1.51 μs, Fock |0⟩, QCRB: 230.46838010018095
# Beta: 1.56 μs, Fock |0⟩, QCRB: 397.58949876268565
# Simulating Fock State |1⟩ (Ancilla Readout)...
# Beta: 0.01 μs, Fock |1⟩, QCRB: 631.1414310771867
# Beta: 0.06 μs, Fock |1⟩, QCRB: 17.685195513230923
# Beta: 0.11 μs, Fock |1⟩, QCRB: 5.3200712584180545
# Beta: 0.16 μs, Fock |1⟩, QCRB: 2.5686514903629236
# Beta: 0.21 μs, Fock |1⟩, QCRB: 1.5297509415103465
# Beta: 0.26 μs, Fock |1⟩, QCRB: 1.0328704814193848
# Beta: 0.31 μs, Fock |1⟩, QCRB: 0.7571938557716789
# Beta: 0.36 μs, Fock |1⟩, QCRB: 0.5892831345862728
# Beta: 0.41 μs, Fock |1⟩, QCRB: 0.4806637994432055
# Beta: 0.46 μs, Fock |1⟩, QCRB: 0.40661449699217206
# Beta: 0.51 μs, Fock |1⟩, QCRB: 0.35505091086802154
# Beta: 0.56 μs, Fock |1⟩, QCRB: 0.31822483108206756
# Beta: 0.61 μs, Fock |1⟩, QCRB: 0.2920473300928232
# Beta: 0.66 μs, Fock |1⟩, QCRB: 0.27364798625528686
# Beta: 0.71 μs, Fock |1⟩, QCRB: 0.2611837993558186
# Beta: 0.76 μs, Fock |1⟩, QCRB: 0.25366062928784816
# Beta: 0.81 μs, Fock |1⟩, QCRB: 0.25028795223955674
# Beta: 0.86 μs, Fock |1⟩, QCRB: 0.2507015280822846
# Beta: 0.91 μs, Fock |1⟩, QCRB: 0.25464171649689077
# Beta: 0.96 μs, Fock |1⟩, QCRB: 0.26214096614136834
# Beta: 1.01 μs, Fock |1⟩, QCRB: 0.27329839717901244
# Beta: 1.06 μs, Fock |1⟩, QCRB: 0.288504623301468
# Beta: 1.11 μs, Fock |1⟩, QCRB: 0.3081081297945678
# Beta: 1.16 μs, Fock |1⟩, QCRB: 0.33290215593393885
# Beta: 1.21 μs, Fock |1⟩, QCRB: 0.3636882133908586
# Beta: 1.26 μs, Fock |1⟩, QCRB: 0.4016785322442381
# Beta: 1.31 μs, Fock |1⟩, QCRB: 0.44859477781675067
# Beta: 1.36 μs, Fock |1⟩, QCRB: 0.5061477180166359
# Beta: 1.41 μs, Fock |1⟩, QCRB: 0.5775206119613641
# Beta: 1.46 μs, Fock |1⟩, QCRB: 0.6658044141999987
# Beta: 1.51 μs, Fock |1⟩, QCRB: 0.7761291304806076
# Beta: 1.56 μs, Fock |1⟩, QCRB: 0.9151296295839018
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
 cutoff = 20
        b = FockBasis(cutoff)
        vac = fockstate(sim_mode, 0)
        z = 0.5 * exp(1im * pi) 
        squeeze_op = squeeze(sim_mode, z)
        ψ_mode = squeeze_op * vac
    ψ_initial = ψ_ion ⊗ ψ_mode
    
    # APPLY SIGNAL FIRST: Create the perturbed initial state
    ψ_initial_perturbed = D_system * ψ_initial
# Out:
# MethodError: no method matching squeeze(::VibrationalMode, ::ComplexF64)
#
# The function `squeeze` exists, but no method is defined for this combination of argument types.
#
#
#
# Closest candidates are:
#
#   squeeze(!Matched::SpinBasis, ::T) where T<:Number
#
#    @ QuantumOpticsBase C:\Users\jewoo\.julia\packages\QuantumOpticsBase\u7a0b\src\spin.jl:120
#
#   squeeze(!Matched::FockBasis, ::T) where T<:Number
#
#    @ QuantumOpticsBase C:\Users\jewoo\.julia\packages\QuantumOpticsBase\u7a0b\src\fock.jl:76
#
#   squeeze(!Matched::Type{T}, !Matched::SpinBasis, !Matched::Number) where T
#
#    @ QuantumOpticsBase C:\Users\jewoo\.julia\packages\QuantumOpticsBase\u7a0b\src\spin.jl:113
#
#   ...
#
#
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\jewoo\projects\TestJulia\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:5

# %%
sim_mode = zmodes(trap)[1]
    
    # 1. Create a temporary standard FockBasis of the EXACT same dimension
    temp_fock_basis = FockBasis(sim_mode.N)
    
    # 2. Use QuantumOptics to calculate the complex squeeze matrix
    z = 0.5 * exp(1im * pi) 
    S_fock = squeeze(temp_fock_basis, z) 
    
    # 3. THE FIX: Wrap the raw matrix data back into the IonSim mode!
    squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
    
    # 4. Build the vacuum state directly on the IonSim mode
    vac = fockstate(sim_mode, 0)
    
    # 5. Apply the wrapped squeeze operator
    ψ_mode = squeeze_op * vac
    
    # 6. Tensor the spin and the mode together
    ψ_initial = ψ_ion ⊗ ψ_mode
    
    # NOW APPLY SIGNAL: The dimensions and types match perfectly!
    ψ_initial_perturbed = D_system * ψ_initial
# Out:
# Ket(dim=42)
#   basis: [⁴⁰Ca ⊗ VibrationalMode(ν=1.9e6, axis=ẑ, N=20)]
#    0.6658412836923923 + 0.0im
#   -0.6658412836923923 - 0.0im
#                   0.0 + 0.00973537964896454im
#                  -0.0 - 0.00973537964896454im
#   0.21747375837055205 - 3.0e-17im
#  -0.21747375837055205 + 3.0e-17im
#                   0.0 + 0.00550913786423412im
#                  -0.0 - 0.00550913786423412im
#   0.08699385347779022 - 2.0e-17im
#  -0.08699385347779022 + 2.0e-17im
#                       ⋮
#     -0.00061454539498 + 0.0im
#                   0.0 + 3.667166195171e-5im
#                  -0.0 - 3.667166195171e-5im
#    0.0002648475541853 - 0.0im
#   -0.0002648475541853 + 0.0im
#                   0.0 + 1.823944967897e-5im
#                  -0.0 - 1.823944967897e-5im
#   0.00014866880846163 - 0.0im
#  -0.00014866880846163 + 0.0im

# %%
# ---------------------------------------------------------
# QCRB Simulation Loop: Squeezed vs Vacuum
# ---------------------------------------------------------
t_max = 1.6
time_steps = 0.01:0.05:t_max 
states = 0:1 
ψ_ion = normalize(ion["g"] - ion["e"])
d_alpha = 0.01

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(time_steps))

# Pre-build the signal operator once to save loop time
sim_mode = zmodes(trap)[1]
D_signal = IonSim.displace(sim_mode, im * d_alpha)
I_spin = identityoperator(ion["g"].basis)
D_system = I_spin ⊗ D_signal

# Squeezing parameter
r_squeeze = 0.5

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 0
        println("Simulating Ordinary Vacuum |0⟩...")
        ψ_mode = fockstate(sim_mode, 0)
        label_sim = "Simulated Vacuum |0⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        # 1. Trick QuantumOptics into calculating the matrix
        temp_fock_basis = FockBasis(sim_mode.N)
        
        # 2. Squeeze in momentum (anti-squeeze in position)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        # 3. Wrap it back into IonSim
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 0)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |0⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    
    # APPLY SIGNAL FIRST: Create the perturbed initial state
    ψ_initial_perturbed = D_system * ψ_initial
    
    for (j, t) in enumerate(time_steps)
        # 1. Base Trajectory (No Signal)
        sol1 = protocol(ψ_initial, 1, t)
        ancilla_base = ptrace(sol1, 2) 
        
        # 2. Perturbed Trajectory (Signal happened before SDF readout)
        sol2 = protocol(ψ_initial_perturbed, 1, t)
        ancilla_perturbed = ptrace(sol2, 2)
        
        # 3. Calculate true Ancilla QCRB
        qfi, qcrb = calculate_qcrb(ancilla_base, ancilla_perturbed, d_alpha)
        push!(qcrb_values, qcrb)
        
        qcrb_matrix[i, j] = qcrb
        println("Beta: ", round(t, digits=2), " μs, State: ", n==0 ? "Vacuum" : "Squeezed", ", QCRB: ", qcrb)
    end
    
    # Plot simulation as scatter dots
    PyPlot.plot(time_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# ---------------------------------------------------------
# Analytical Theory Overlay
# ---------------------------------------------------------
# High-resolution X-axis to capture smooth curves
alphas_theory = range(0.01, stop=t_max, length=1000)

# 1. Theory for Ordinary Vacuum (r = 0)
# Formula: exp(4x^2) / (16x^2)
qcrb_theory_0 = @. exp(4 * alphas_theory^2) / (16 * alphas_theory^2 + 1e-15)

# 2. Theory for Squeezed Vacuum
# Because we used a phase of pi, the wavepacket is anti-squeezed (wider) in the X direction.
# This suppresses the wavepacket separation penalty by e^(-2r).
suppression_factor = exp(-2 * r_squeeze)
qcrb_theory_sq = @. exp(4 * alphas_theory^2 * suppression_factor) / (16 * alphas_theory^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_0, "--", color="black", linewidth=2, label="Theory Vacuum")
PyPlot.plot(alphas_theory, qcrb_theory_sq, ":", color="red", linewidth=2.5, label="Theory Squeezed (r=$r_squeeze)")

# ---------------------------------------------------------
# Plot Formatting
# ---------------------------------------------------------
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) # Confidently constrain the Y-axis so infinities don't compress the graph

PyPlot.xlabel("Laser Exposure Time [Displacement α] (μs)", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Squeezed Metrology", fontsize=14)

# Put legend in the lower right so it doesn't cover the upper-left curves
PyPlot.legend(loc="lower right", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |0⟩...
# Beta: 0.01 μs, State: Vacuum, QCRB: 631.2804651034652
# Beta: 0.06 μs, State: Vacuum, QCRB: 17.853317960472243
# Beta: 0.11 μs, State: Vacuum, QCRB: 5.480696619445355
# Beta: 0.16 μs, State: Vacuum, QCRB: 2.7366460232628054
# Beta: 0.21 μs, State: Vacuum, QCRB: 1.7067531376906622
# Beta: 0.26 μs, State: Vacuum, QCRB: 1.2222911786859958
# Beta: 0.31 μs, State: Vacuum, QCRB: 0.9620008158741804
# Beta: 0.36 μs, State: Vacuum, QCRB: 0.8140242674113498
# Beta: 0.41 μs, State: Vacuum, QCRB: 0.730716001992581
# Beta: 0.46 μs, State: Vacuum, QCRB: 0.689116207868187
# Beta: 0.51 μs, State: Vacuum, QCRB: 0.6789473672891637
# Beta: 0.56 μs, State: Vacuum, QCRB: 0.695545159072008
# Beta: 0.61 μs, State: Vacuum, QCRB: 0.7385048533548646
# Beta: 0.66 μs, State: Vacuum, QCRB: 0.8106020910282363
# Beta: 0.71 μs, State: Vacuum, QCRB: 0.9183011534542179
# Beta: 0.76 μs, State: Vacuum, QCRB: 1.071108067235525
# Beta: 0.81 μs, State: Vacuum, QCRB: 1.2863343910699536
# Beta: 0.86 μs, State: Vacuum, QCRB: 1.586894629072432
# Beta: 0.91 μs, State: Vacuum, QCRB: 2.011107225018214
# Beta: 0.96 μs, State: Vacuum, QCRB: 2.6163705142388256
# Beta: 1.01 μs, State: Vacuum, QCRB: 3.4879377979552673
# Beta: 1.06 μs, State: Vacuum, QCRB: 4.772931679569251
# Beta: 1.11 μs, State: Vacuum, QCRB: 6.683163802659482
# Beta: 1.16 μs, State: Vacuum, QCRB: 9.596310642984157
# Beta: 1.21 μs, State: Vacuum, QCRB: 14.102597773148151
# Beta: 1.26 μs, State: Vacuum, QCRB: 21.20713981083698
# Beta: 1.31 μs, State: Vacuum, QCRB: 32.680490350766675
# Beta: 1.36 μs, State: Vacuum, QCRB: 51.43305148401149
# Beta: 1.41 μs, State: Vacuum, QCRB: 82.97179047311695
# Beta: 1.46 μs, State: Vacuum, QCRB: 136.7046244690053
# Beta: 1.51 μs, State: Vacuum, QCRB: 230.46838010018095
# Beta: 1.56 μs, State: Vacuum, QCRB: 397.58949876268565
# Simulating Squeezed Vacuum (r = 0.5)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 631.1414310771867
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.685195513230923
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.3200712584180545
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.5686514903629236
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.5297509415103465
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.0328704814193848
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.7571938557716789
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.5892831345862728
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.4806637994432055
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.40661449699217206
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.35505091086802154
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.31822483108206756
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.2920473300928232
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.27364798625528686
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.2611837993558186
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.25366062928784816
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.25028795223955674
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.2507015280822846
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.25464171649689077
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.26214096614136834
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.27329839717901244
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.288504623301468
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.3081081297945678
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.33290215593393885
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.3636882133908586
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.4016785322442381
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.44859477781675067
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.5061477180166359
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.5775206119613641
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.6658044141999987
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.7761291304806076
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.9151296295839018
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
# ---------------------------------------------------------
# QCRB Simulation Loop: Squeezed vs Vacuum
# ---------------------------------------------------------
t_max = 1.6
time_steps = 0.01:0.05:t_max 
states = 0:1 
ψ_ion = normalize(ion["g"] - ion["e"])
d_alpha = 0.01

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(time_steps))

# Pre-build the signal operator once to save loop time
sim_mode = zmodes(trap)[1]
D_signal = IonSim.displace(sim_mode, im * d_alpha)
I_spin = identityoperator(ion["g"].basis)
D_system = I_spin ⊗ D_signal

# Squeezing parameter
r_squeeze = 0.5

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 0
        println("Simulating Ordinary Vacuum |1⟩...")
        ψ_mode = fockstate(sim_mode, 1)
        label_sim = "Simulated Vacuum |1⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        # 1. Trick QuantumOptics into calculating the matrix
        temp_fock_basis = FockBasis(sim_mode.N)
        
        # 2. Squeeze in momentum (anti-squeeze in position)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        # 3. Wrap it back into IonSim
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 1)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |1⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    
    # APPLY SIGNAL FIRST: Create the perturbed initial state
    ψ_initial_perturbed = D_system * ψ_initial
    
    for (j, t) in enumerate(time_steps)
        # 1. Base Trajectory (No Signal)
        sol1 = protocol(ψ_initial, 1, t)
        ancilla_base = ptrace(sol1, 2) 
        
        # 2. Perturbed Trajectory (Signal happened before SDF readout)
        sol2 = protocol(ψ_initial_perturbed, 1, t)
        ancilla_perturbed = ptrace(sol2, 2)
        
        # 3. Calculate true Ancilla QCRB
        qfi, qcrb = calculate_qcrb(ancilla_base, ancilla_perturbed, d_alpha)
        push!(qcrb_values, qcrb)
        
        qcrb_matrix[i, j] = qcrb
        println("Beta: ", round(t, digits=2), " μs, State: ", n==0 ? "Vacuum" : "Squeezed", ", QCRB: ", qcrb)
    end
    
    # Plot simulation as scatter dots
    PyPlot.plot(time_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# ---------------------------------------------------------
# Analytical Theory Overlay
# ---------------------------------------------------------
# High-resolution X-axis to capture smooth curves
alphas_theory = range(0.01, stop=t_max, length=1000)

# 1. Theory for Ordinary Vacuum (r = 0)
# Formula: exp(4x^2) / (16x^2)
qcrb_theory_0 = @. exp(4 * alphas_theory^2) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

# 2. Theory for Squeezed Vacuum
# Because we used a phase of pi, the wavepacket is anti-squeezed (wider) in the X direction.
# This suppresses the wavepacket separation penalty by e^(-2r).
suppression_factor = exp(-2 * r_squeeze)
qcrb_theory_sq = @. exp(4 * alphas_theory^2 * suppression_factor) / (16 * alphas_theory^2 * (1 - 4 * alphas_theory^2)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_0, "--", color="black", linewidth=2, label="Theory Vacuum")
PyPlot.plot(alphas_theory, qcrb_theory_sq, ":", color="red", linewidth=2.5, label="Theory Squeezed (r=$r_squeeze)")

# ---------------------------------------------------------
# Plot Formatting
# ---------------------------------------------------------
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) # Confidently constrain the Y-axis so infinities don't compress the graph

PyPlot.xlabel("Laser Exposure Time [Displacement α] (μs)", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Squeezed Metrology", fontsize=14)

# Put legend in the lower left so it doesn't cover the data curves
PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |1⟩...
# Beta: 0.01 μs, State: Vacuum, QCRB: 635.5048649073302
# Beta: 0.06 μs, State: Vacuum, QCRB: 18.46572195657832
# Beta: 0.11 μs, State: Vacuum, QCRB: 6.075485042479804
# Beta: 0.16 μs, State: Vacuum, QCRB: 3.4014549469930544
# Beta: 0.21 μs, State: Vacuum, QCRB: 2.5131035102380057
# Beta: 0.26 μs, State: Vacuum, QCRB: 2.2815526280535408
# Beta: 0.31 μs, State: Vacuum, QCRB: 2.503246606219698
# Beta: 0.36 μs, State: Vacuum, QCRB: 3.416254194454021
# Beta: 0.41 μs, State: Vacuum, QCRB: 6.4303548830837
# Beta: 0.46 μs, State: Vacuum, QCRB: 25.113476870716628
# Beta: 0.51 μs, State: Vacuum, QCRB: 924.0332973025073
# Beta: 0.56 μs, State: Vacuum, QCRB: 12.430203839980235
# Beta: 0.61 μs, State: Vacuum, QCRB: 3.3848656768484973
# Beta: 0.66 μs, State: Vacuum, QCRB: 1.5748755594554344
# Beta: 0.71 μs, State: Vacuum, QCRB: 0.9397885711078935
# Beta: 0.76 μs, State: Vacuum, QCRB: 0.6554021714610763
# Beta: 0.81 μs, State: Vacuum, QCRB: 0.5089983908375653
# Beta: 0.86 μs, State: Vacuum, QCRB: 0.43044360946408117
# Beta: 0.91 μs, State: Vacuum, QCRB: 0.38992761104897733
# Beta: 0.96 μs, State: Vacuum, QCRB: 0.3746489471245907
# Beta: 1.01 μs, State: Vacuum, QCRB: 0.3790754400967892
# Beta: 1.06 μs, State: Vacuum, QCRB: 0.40191153244229544
# Beta: 1.11 μs, State: Vacuum, QCRB: 0.4445037544660193
# Beta: 1.16 μs, State: Vacuum, QCRB: 0.5115924509287086
# Beta: 1.21 μs, State: Vacuum, QCRB: 0.6109593374195732
# Beta: 1.26 μs, State: Vacuum, QCRB: 0.755494701053418
# Beta: 1.31 μs, State: Vacuum, QCRB: 0.9667441528480615
# Beta: 1.36 μs, State: Vacuum, QCRB: 1.2759412315762813
# Beta: 1.41 μs, State: Vacuum, QCRB: 1.739240122425033
# Beta: 1.46 μs, State: Vacuum, QCRB: 2.4406073209990073
# Beta: 1.51 μs, State: Vacuum, QCRB: 3.527404634277887
# Beta: 1.56 μs, State: Vacuum, QCRB: 5.248024181113238
# Simulating Squeezed Vacuum (r = 0.5)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 631.4364312221854
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.914176151919946
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.539693698680327
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.786159199056212
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.7552000425380145
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.2764325989680994
# Beta: 0.31 μs, State: Squeezed, QCRB: 1.027627465163819
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.8984522749819112
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.8447357212529816
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.85074078687382
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.9193451631566301
# Beta: 0.56 μs, State: Squeezed, QCRB: 1.0750901026141726
# Beta: 0.61 μs, State: Squeezed, QCRB: 1.3818042065273384
# Beta: 0.66 μs, State: Squeezed, QCRB: 2.0170668018999987
# Beta: 0.71 μs, State: Squeezed, QCRB: 3.593544821792006
# Beta: 0.76 μs, State: Squeezed, QCRB: 9.362000219327019
# Beta: 0.81 μs, State: Squeezed, QCRB: 81.76064805026546
# Beta: 0.86 μs, State: Squeezed, QCRB: 44.85298771607242
# Beta: 0.91 μs, State: Squeezed, QCRB: 6.421234974275396
# Beta: 0.96 μs, State: Squeezed, QCRB: 2.369729040175938
# Beta: 1.01 μs, State: Squeezed, QCRB: 1.2227389924761174
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.7496792791370472
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.5145164147942485
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.38153848069969043
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.3004592457068754
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.24831948667907885
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.21356178319545566
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.19030453824017013
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.1748556057681896
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.16531580961227693
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.1604783711347515
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.15974988037238702
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
# ---------------------------------------------------------
# QCRB Simulation Loop: Squeezed vs Vacuum
# ---------------------------------------------------------
t_max = 1.6
time_steps = 0.01:0.05:t_max 
states = 0:1 
ψ_ion = normalize(ion["g"] - ion["e"])
d_alpha = 0.01

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(time_steps))

# Pre-build the signal operator once to save loop time
sim_mode = zmodes(trap)[1]
D_signal = IonSim.displace(sim_mode, im * d_alpha)
I_spin = identityoperator(ion["g"].basis)
D_system = I_spin ⊗ D_signal


r_squeezes = 0.0:0.1:1.0
 for r_squeeze in r_squeezes
    qcrb_values = Float64[]
    
 
       
    println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
    # 1. Trick QuantumOptics into calculating the matrix
    temp_fock_basis = FockBasis(sim_mode.N)
    
    # 2. Squeeze in momentum (anti-squeeze in position)
    z = r_squeeze * exp(1im * pi) 
    S_fock = squeeze(temp_fock_basis, z) 
    
    # 3. Wrap it back into IonSim
    squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
    vac = fockstate(sim_mode, 0)
    ψ_mode = squeeze_op * vac
    
    label_sim = "Simulated Squeezed |0⟩ (r=$r_squeeze)"
    color_sim = "tab:purple"

    
    ψ_initial = ψ_ion ⊗ ψ_mode
    
    # APPLY SIGNAL FIRST: Create the perturbed initial state
    ψ_initial_perturbed = D_system * ψ_initial
    
    for (j, t) in enumerate(time_steps)
        # 1. Base Trajectory (No Signal)
        sol1 = protocol(ψ_initial, 1, t)
        ancilla_base = ptrace(sol1, 2) 
        
        # 2. Perturbed Trajectory (Signal happened before SDF readout)
        sol2 = protocol(ψ_initial_perturbed, 1, t)
        ancilla_perturbed = ptrace(sol2, 2)
        
        # 3. Calculate true Ancilla QCRB
        qfi, qcrb = calculate_qcrb(ancilla_base, ancilla_perturbed, d_alpha)
        push!(qcrb_values, qcrb)
        
        qcrb_matrix[j] = qcrb
        println("Beta: ", round(t, digits=2), " μs, State: ",  "Squeezed", ", QCRB: ", qcrb)
    end
    
    # Plot simulation as scatter dots
    PyPlot.plot(time_steps, qcrb_values, "o", markersize=7, label=label_sim)
end

# ---------------------------------------------------------
# Analytical Theory Overlay
# ---------------------------------------------------------
# High-resolution X-axis to capture smooth curves
alphas_theory = range(0.01, stop=t_max, length=1000)

# 1. Theory for Ordinary Vacuum (r = 0)
# Formula: exp(4x^2) / (16x^2)
qcrb_theory_0 = @. exp(4 * alphas_theory^2) / (16 * alphas_theory^2 + 1e-15)

# 2. Theory for Squeezed Vacuum
# Because we used a phase of pi, the wavepacket is anti-squeezed (wider) in the X direction.
# This suppresses the wavepacket separation penalty by e^(-2r).
suppression_factor = exp(-2 * r_squeeze)
qcrb_theory_sq = @. exp(4 * alphas_theory^2 * suppression_factor) / (16 * alphas_theory^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_0, "--", color="black", linewidth=2, label="Theory Vacuum")
PyPlot.plot(alphas_theory, qcrb_theory_sq, ":", color="red", linewidth=2.5, label="Theory Squeezed (r=$r_squeeze)")

# ---------------------------------------------------------
# Plot Formatting
# ---------------------------------------------------------
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) # Confidently constrain the Y-axis so infinities don't compress the graph

PyPlot.xlabel("Laser Exposure Time [Displacement α] (μs)", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Squeezed Metrology", fontsize=14)

# Put legend in the lower right so it doesn't cover the upper-left curves
PyPlot.legend(loc="lower right", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Squeezed Vacuum (r = 0.0)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 631.2804651034652
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.853317960472243
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.480696619445355
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.7366460232628054
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.7067531376906622
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.2222911786859958
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.9620008158741804
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.8140242674113498
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.730716001992581
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.689116207868187
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.6789473672891637
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.695545159072008
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.7385048533548646
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.8106020910282363
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.9183011534542179
# Beta: 0.76 μs, State: Squeezed, QCRB: 1.071108067235525
# Beta: 0.81 μs, State: Squeezed, QCRB: 1.2863343910699536
# Beta: 0.86 μs, State: Squeezed, QCRB: 1.586894629072432
# Beta: 0.91 μs, State: Squeezed, QCRB: 2.011107225018214
# Beta: 0.96 μs, State: Squeezed, QCRB: 2.6163705142388256
# Beta: 1.01 μs, State: Squeezed, QCRB: 3.4879377979552673
# Beta: 1.06 μs, State: Squeezed, QCRB: 4.772931679569251
# Beta: 1.11 μs, State: Squeezed, QCRB: 6.683163802659482
# Beta: 1.16 μs, State: Squeezed, QCRB: 9.596310642984157
# Beta: 1.21 μs, State: Squeezed, QCRB: 14.102597773148151
# Beta: 1.26 μs, State: Squeezed, QCRB: 21.20713981083698
# Beta: 1.31 μs, State: Squeezed, QCRB: 32.680490350766675
# Beta: 1.36 μs, State: Squeezed, QCRB: 51.43305148401149
# Beta: 1.41 μs, State: Squeezed, QCRB: 82.97179047311695
# Beta: 1.46 μs, State: Squeezed, QCRB: 136.7046244690053
# Beta: 1.51 μs, State: Squeezed, QCRB: 230.46838010018095
# Beta: 1.56 μs, State: Squeezed, QCRB: 397.58949876268565
# Simulating Squeezed Vacuum (r = 0.1)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 631.2171764630472
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.804548524039607
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.432261600945512
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.6870596971028005
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.6541006574750758
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.1648741472392208
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.898386255274392
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.7421239466114171
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.6480884144627233
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.5924918306890679
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.5638496167720614
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.5559008029350423
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.5660606864217517
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.5937195763367081
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.6402872998348549
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.708640846050736
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.8043506452231322
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.9346428799945419
# Beta: 0.91 μs, State: Squeezed, QCRB: 1.1114989934640214
# Beta: 0.96 μs, State: Squeezed, QCRB: 1.3518292649389834
# Beta: 1.01 μs, State: Squeezed, QCRB: 1.6790124855559698
# Beta: 1.06 μs, State: Squeezed, QCRB: 2.132123479172291
# Beta: 1.11 μs, State: Squeezed, QCRB: 2.760997714625889
# Beta: 1.16 μs, State: Squeezed, QCRB: 3.6520847477962675
# Beta: 1.21 μs, State: Squeezed, QCRB: 4.926565181361432
# Beta: 1.26 μs, State: Squeezed, QCRB: 6.775300799347565
# Beta: 1.31 μs, State: Squeezed, QCRB: 9.511049068337412
# Beta: 1.36 μs, State: Squeezed, QCRB: 13.589223876641967
# Beta: 1.41 μs, State: Squeezed, QCRB: 19.819684976785435
# Beta: 1.46 μs, State: Squeezed, QCRB: 29.41988717063122
# Beta: 1.51 μs, State: Squeezed, QCRB: 44.51298100478025
# Beta: 1.56 μs, State: Squeezed, QCRB: 68.64663277273921
# Simulating Squeezed Vacuum (r = 0.2)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 629.1673592319926
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.717656048296565
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.387030160889628
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.643894712148167
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.6100913630076708
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.1185560622498338
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.8486347295154705
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.6875068254214262
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.5871337317312465
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.5232197056350608
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.4840191826878856
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.462497383037452
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.455120154881678
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.4599502019990404
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.47650622105498
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.5051431491736188
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.5475233026472142
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.6057702378008502
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.6839299232203342
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.7873104172021721
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.9229437439369298
# Beta: 1.06 μs, State: Squeezed, QCRB: 1.1025593355416703
# Beta: 1.11 μs, State: Squeezed, QCRB: 1.3396399932588803
# Beta: 1.16 μs, State: Squeezed, QCRB: 1.657241017051865
# Beta: 1.21 μs, State: Squeezed, QCRB: 2.084573977049043
# Beta: 1.26 μs, State: Squeezed, QCRB: 2.665548463089584
# Beta: 1.31 μs, State: Squeezed, QCRB: 3.4677499606070685
# Beta: 1.36 μs, State: Squeezed, QCRB: 4.579624302410032
# Beta: 1.41 μs, State: Squeezed, QCRB: 6.152920017366145
# Beta: 1.46 μs, State: Squeezed, QCRB: 8.390307822043965
# Beta: 1.51 μs, State: Squeezed, QCRB: 11.625533459207858
# Beta: 1.56 μs, State: Squeezed, QCRB: 16.367109473370935
# Simulating Squeezed Vacuum (r = 0.3)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 630.4229462379893
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.728489169404615
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.356485562408981
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.6120376554734794
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.5769300881050459
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.0831632449870132
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.8104766999361125
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.6460431693883064
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.541530344185091
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.47262773817626386
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.42723072125990696
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.3978282710556653
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.3805664980496905
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.37312747503346483
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.37405137112458975
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.3827914246419585
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.39951611303139073
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.42469623020892977
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.45956435342895713
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.5057478913357123
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.5655415084754937
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.6427743025952407
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.7413453160313088
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.8683475758643561
# Beta: 1.21 μs, State: Squeezed, QCRB: 1.0317377014775178
# Beta: 1.26 μs, State: Squeezed, QCRB: 1.2432327425263825
# Beta: 1.31 μs, State: Squeezed, QCRB: 1.5201469673949517
# Beta: 1.36 μs, State: Squeezed, QCRB: 1.882863992833829
# Beta: 1.41 μs, State: Squeezed, QCRB: 2.366222715826913
# Beta: 1.46 μs, State: Squeezed, QCRB: 3.0117012164239476
# Beta: 1.51 μs, State: Squeezed, QCRB: 3.8857556511002613
# Beta: 1.56 μs, State: Squeezed, QCRB: 5.082024564754801
# Simulating Squeezed Vacuum (r = 0.4)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 631.4862481501908
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.752705220995242
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.3429404152580675
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.590701199255346
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.5519764329431793
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.056106441753048
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.7813040932945409
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.6145966787019702
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.5075147979773277
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.43537152738024365
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.38610580937029193
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.352017679275302
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.32918497505855226
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.31478734786880536
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.30716230217648255
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.305396356876005
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.3090393426167222
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.3179278519827702
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.3322452448230261
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.35240757192033006
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.37911926563349296
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.41366028250989173
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.4572438373668613
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.5121592399553221
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.5808764964041396
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.6669184178460706
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.7754033225612615
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.9117757226134556
# Beta: 1.41 μs, State: Squeezed, QCRB: 1.0856458352215475
# Beta: 1.46 μs, State: Squeezed, QCRB: 1.307249500459426
# Beta: 1.51 μs, State: Squeezed, QCRB: 1.593062688359301
# Beta: 1.56 μs, State: Squeezed, QCRB: 1.965018175100721
# Simulating Squeezed Vacuum (r = 0.5)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 631.1414310771867
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.685195513230923
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.3200712584180545
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.5686514903629236
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.5297509415103465
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.0328704814193848
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.7571938557716789
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.5892831345862728
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.4806637994432055
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.40661449699217206
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.35505091086802154
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.31822483108206756
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.2920473300928232
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.27364798625528686
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.2611837993558186
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.25366062928784816
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.25028795223955674
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.2507015280822846
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.25464171649689077
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.26214096614136834
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.27329839717901244
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.288504623301468
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.3081081297945678
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.33290215593393885
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.3636882133908586
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.4016785322442381
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.44859477781675067
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.5061477180166359
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.5775206119613641
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.6658044141999987
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.7761291304806076
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.9151296295839018
# Simulating Squeezed Vacuum (r = 0.6)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 627.3503290219061
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.656205598462517
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.3018620202012325
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.5516916082348517
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.5120889940041644
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.0150899035296823
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.7385501395849807
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.569768860426713
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.460053813874912
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.38475807208898377
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.33171060900099164
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.293194584914791
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.26499052347946933
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.24421273351224745
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.2289627579206386
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.21816706223265894
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.21091930258594058
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.20673670966856092
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.20524990332193563
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.20628836442393905
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.2097200817637133
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.21562181081473916
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.2240569720163723
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.23528058086490894
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.24959088730071777
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.2674301973157082
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.2894845186013458
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.3163896042073436
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.34943676366931226
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.389784865659064
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.4394842344048406
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.5011227051566737
# Simulating Squeezed Vacuum (r = 0.7)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 624.6777064614398
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.316549519532956
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.223108672539636
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.516460205887866
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.4890352436950718
# Beta: 0.26 μs, State: Squeezed, QCRB: 0.9958290733431961
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.7208351245512518
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.5525981234210777
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.4427956414316249
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.36710238424147174
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.31341558317088714
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.27400606666599026
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.24468273186296025
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.22260286403054086
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.20576728033267463
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.19315445702557846
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.18376955585629173
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.17711297974929094
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.17275645023914407
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.1704326191090323
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.16994007140977402
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.1712202231349579
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.17424649761048422
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.17907074214607147
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.1858036170409097
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.19462380572154805
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.20585495307678123
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.21977876920617073
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.23702029136588887
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.2581367625744198
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.28414422928206423
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.31628170016506585
# Simulating Squeezed Vacuum (r = 0.8)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 633.5326497925041
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.625229140222423
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.272288277917427
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.526369941612322
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.4877433259804613
# Beta: 0.26 μs, State: Squeezed, QCRB: 0.9900371561811782
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.7128206065581232
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.5431931037600151
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.43246718832354464
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.35597264162725933
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.30155847273135966
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.2613711990846313
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.23123246508645798
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.20817361171822032
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.19037579391234624
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.17664167910060632
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.16603940740136605
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.15802584941594278
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.1521181348831683
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.14801430076648375
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.14550529040247592
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.14445044044180513
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.14478833952706874
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.14650178458474994
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.14961749364886545
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.15421035991447038
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.16045575899691808
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.16849705681451518
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.1786791951708906
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.19133922929115044
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.20704055002303093
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.2264987827330284
# Simulating Squeezed Vacuum (r = 0.9)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 637.5751425829488
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.676927827423693
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.27796315491363
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.5245935661836243
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.4825474120800755
# Beta: 0.26 μs, State: Squeezed, QCRB: 0.9835860946655341
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.7058086407928532
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.5359615196428619
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.42511678178642825
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.3484840916886026
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.2938354483216434
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.2533130517567693
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.2225525864651263
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.1989582636055991
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.1805447067416789
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.16623074641833419
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.1549953373424036
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.14626326120140384
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.13956224071169576
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.1345456406688764
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.13100259477366782
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.12876158412270586
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.12774337660915
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.1279044399010963
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.1292322854345302
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.13174389524413
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.13553870314564684
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.14069419539355255
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.14743176480711526
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.1559491833209435
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.1666123014878913
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.17988429165905462
# Simulating Squeezed Vacuum (r = 1.0)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 628.7572558630201
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.648056670189064
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.270172769647659
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.513310266286749
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.473629252861546
# Beta: 0.26 μs, State: Squeezed, QCRB: 0.9756414303929097
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.6988451499860465
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.5301156383209074
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.4203487112481206
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.34455782218172815
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.29037017690694183
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.249872620942386
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.2189496213656261
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.19490621401475958
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.17606605996451452
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.16129427539623198
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.14966777564165484
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.14057754062681077
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.133444153099816
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.1279244672605815
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.1237990324955495
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.12086974734465532
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.1190923243327944
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.11840659405948487
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.11877758863564043
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.12017802597940187
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.12262995936923438
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.12617139093219304
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.13093918045710526
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.13706462280230997
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.1447934645059859
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.15441155643312685
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
# ---------------------------------------------------------
# QCRB Simulation Loop: Squeezed vs Ordinary Fock |1⟩
# ---------------------------------------------------------
t_max = 1.6
time_steps = 0.01:0.05:t_max 
state_types = ["Ordinary", "Squeezed"] 
ψ_ion = normalize(ion["g"] - ion["e"])
d_alpha = 0.01

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(state_types), length(time_steps))

# Pre-build the signal operator once to save loop time
sim_mode = zmodes(trap)[1]
D_signal = IonSim.displace(sim_mode, im * d_alpha)
I_spin = identityoperator(ion["g"].basis)
D_system = I_spin ⊗ D_signal

# Squeezing parameter
r_squeeze = 0.5

for (i, state_type) in enumerate(state_types)
    qcrb_values = Float64[]
    
    if state_type == "Ordinary"
        println("Simulating Ordinary Fock |1⟩...")
        ψ_mode = fockstate(sim_mode, 1)
        label_sim = "Simulated Ordinary |1⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Fock |1⟩ (r = $r_squeeze)...")
        # 1. Trick QuantumOptics into calculating the matrix
        temp_fock_basis = FockBasis(sim_mode.N)
        
        # 2. Squeeze in momentum (anti-squeeze in position)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        # 3. Wrap it back into IonSim
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        
        # Apply squeeze operator to Fock state |1>
        fock_1 = fockstate(sim_mode, 1)
        ψ_mode = squeeze_op * fock_1
        
        label_sim = "Simulated Squeezed |1⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    
    # APPLY SIGNAL FIRST: Create the perturbed initial state
    ψ_initial_perturbed = D_system * ψ_initial
    
    for (j, t) in enumerate(time_steps)
        # 1. Base Trajectory (No Signal)
        sol1 = protocol(ψ_initial, 1, t)
        ancilla_base = ptrace(sol1, 2) 
        
        # 2. Perturbed Trajectory (Signal happened before SDF readout)
        sol2 = protocol(ψ_initial_perturbed, 1, t)
        ancilla_perturbed = ptrace(sol2, 2)
        
        # 3. Calculate true Ancilla QCRB
        qfi, qcrb = calculate_qcrb(ancilla_base, ancilla_perturbed, d_alpha)
        push!(qcrb_values, qcrb)
        
        qcrb_matrix[i, j] = qcrb
        println("Beta: ", round(t, digits=2), " μs, State: ", state_type, ", QCRB: ", qcrb)
    end
    
    # Plot simulation as scatter dots
    PyPlot.plot(time_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# ---------------------------------------------------------
# Analytical Theory Overlay
# ---------------------------------------------------------
# High-resolution X-axis to capture smooth curves
alphas_theory = range(0.01, stop=t_max, length=1000)

# 1. Theory for Ordinary Fock |1⟩
# Let x = 4 * α^2. The formula is exp(x) / (16α^2 * (1 - x)^2)
x_norm = @. 4 * alphas_theory^2
qcrb_theory_1 = @. exp(x_norm) / (16 * alphas_theory^2 * (1 - x_norm)^2 + 1e-15)

# 2. Theory for Squeezed Fock |1⟩
# Squeezing stretches both the envelope AND the Laguerre ripples by exp(-2r)
# Let x_sq = 4 * α^2 * exp(-2r). The formula is exp(x_sq) / (16α^2 * (1 - x_sq)^2)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
qcrb_theory_sq = @. exp(x_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1, "--", color="black", linewidth=2, label="Theory Ordinary |1⟩")
PyPlot.plot(alphas_theory, qcrb_theory_sq, ":", color="red", linewidth=2.5, label="Theory Squeezed |1⟩ (r=$r_squeeze)")

# ---------------------------------------------------------
# Plot Formatting
# ---------------------------------------------------------
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) # Confidently constrain the Y-axis so infinities don't compress the graph

PyPlot.xlabel(L"Laser Exposure Time [Displacement $\alpha$] ($\mu$s)", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Squeezed Fock |1⟩ Metrology", fontsize=14)

# Put legend in the lower left so it doesn't cover the data curves
PyPlot.legend(loc="upper left", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Fock |1⟩...
# Beta: 0.01 μs, State: Ordinary, QCRB: 635.5048649073302
# Beta: 0.06 μs, State: Ordinary, QCRB: 18.46572195657832
# Beta: 0.11 μs, State: Ordinary, QCRB: 6.075485042479804
# Beta: 0.16 μs, State: Ordinary, QCRB: 3.4014549469930544
# Beta: 0.21 μs, State: Ordinary, QCRB: 2.5131035102380057
# Beta: 0.26 μs, State: Ordinary, QCRB: 2.2815526280535408
# Beta: 0.31 μs, State: Ordinary, QCRB: 2.503246606219698
# Beta: 0.36 μs, State: Ordinary, QCRB: 3.416254194454021
# Beta: 0.41 μs, State: Ordinary, QCRB: 6.4303548830837
# Beta: 0.46 μs, State: Ordinary, QCRB: 25.113476870716628
# Beta: 0.51 μs, State: Ordinary, QCRB: 924.0332973025073
# Beta: 0.56 μs, State: Ordinary, QCRB: 12.430203839980235
# Beta: 0.61 μs, State: Ordinary, QCRB: 3.3848656768484973
# Beta: 0.66 μs, State: Ordinary, QCRB: 1.5748755594554344
# Beta: 0.71 μs, State: Ordinary, QCRB: 0.9397885711078935
# Beta: 0.76 μs, State: Ordinary, QCRB: 0.6554021714610763
# Beta: 0.81 μs, State: Ordinary, QCRB: 0.5089983908375653
# Beta: 0.86 μs, State: Ordinary, QCRB: 0.43044360946408117
# Beta: 0.91 μs, State: Ordinary, QCRB: 0.38992761104897733
# Beta: 0.96 μs, State: Ordinary, QCRB: 0.3746489471245907
# Beta: 1.01 μs, State: Ordinary, QCRB: 0.3790754400967892
# Beta: 1.06 μs, State: Ordinary, QCRB: 0.40191153244229544
# Beta: 1.11 μs, State: Ordinary, QCRB: 0.4445037544660193
# Beta: 1.16 μs, State: Ordinary, QCRB: 0.5115924509287086
# Beta: 1.21 μs, State: Ordinary, QCRB: 0.6109593374195732
# Beta: 1.26 μs, State: Ordinary, QCRB: 0.755494701053418
# Beta: 1.31 μs, State: Ordinary, QCRB: 0.9667441528480615
# Beta: 1.36 μs, State: Ordinary, QCRB: 1.2759412315762813
# Beta: 1.41 μs, State: Ordinary, QCRB: 1.739240122425033
# Beta: 1.46 μs, State: Ordinary, QCRB: 2.4406073209990073
# Beta: 1.51 μs, State: Ordinary, QCRB: 3.527404634277887
# Beta: 1.56 μs, State: Ordinary, QCRB: 5.248024181113238
# Simulating Squeezed Fock |1⟩ (r = 0.5)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 631.4364312221854
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.914176151919946
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.539693698680327
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.786159199056212
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.7552000425380145
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.2764325989680994
# Beta: 0.31 μs, State: Squeezed, QCRB: 1.027627465163819
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.8984522749819112
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.8447357212529816
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.85074078687382
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.9193451631566301
# Beta: 0.56 μs, State: Squeezed, QCRB: 1.0750901026141726
# Beta: 0.61 μs, State: Squeezed, QCRB: 1.3818042065273384
# Beta: 0.66 μs, State: Squeezed, QCRB: 2.0170668018999987
# Beta: 0.71 μs, State: Squeezed, QCRB: 3.593544821792006
# Beta: 0.76 μs, State: Squeezed, QCRB: 9.362000219327019
# Beta: 0.81 μs, State: Squeezed, QCRB: 81.76064805026546
# Beta: 0.86 μs, State: Squeezed, QCRB: 44.85298771607242
# Beta: 0.91 μs, State: Squeezed, QCRB: 6.421234974275396
# Beta: 0.96 μs, State: Squeezed, QCRB: 2.369729040175938
# Beta: 1.01 μs, State: Squeezed, QCRB: 1.2227389924761174
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.7496792791370472
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.5145164147942485
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.38153848069969043
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.3004592457068754
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.24831948667907885
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.21356178319545566
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.19030453824017013
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.1748556057681896
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.16531580961227693
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.1604783711347515
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.15974988037238702
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
PyPlot.clf()
t_max = 3.0
alphas_theory = range(0.01, stop=t_max, length=1000)

x_norm = @. 4 * alphas_theory^2
qcrb_theory_1 = @. exp(x_norm) / (16 * alphas_theory^2 + 1e-15)

# 2. Theory for Squeezed Fock |1⟩
# Squeezing stretches both the envelope AND the Laguerre ripples by exp(-2r)
# Let x_sq = 4 * α^2 * exp(-2r). The formula is exp(x_sq) / (16α^2 * (1 - x_sq)^2)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
qcrb_theory_sq_0 = @. exp(x_sq) / (16 * alphas_theory^2+ 1e-15)

# 1. Theory for Ordinary Fock |1⟩
# Let x = 4 * α^2. The formula is exp(x) / (16α^2 * (1 - x)^2)
x_norm = @. 4 * alphas_theory^2
qcrb_theory_1 = @. exp(x_norm) / (16 * alphas_theory^2 * (1 - x_norm)^2 + 1e-15)

# 2. Theory for Squeezed Fock |1⟩
# Squeezing stretches both the envelope AND the Laguerre ripples by exp(-2r)
# Let x_sq = 4 * α^2 * exp(-2r). The formula is exp(x_sq) / (16α^2 * (1 - x_sq)^2)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
qcrb_theory_sq = @. exp(x_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1, "--", color="black", linewidth=2, label="Theory Ordinary |1⟩")
PyPlot.plot(alphas_theory, qcrb_theory_sq, ":", color="red", linewidth=2.5, label="Theory Squeezed |1⟩ (r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_0, "--", color="blue", linewidth=2, label="Theory Ordinary |0⟩")
PyPlot.plot(alphas_theory, qcrb_theory_sq_0, ":", color="purple", linewidth=2.5, label="Theory Squeezed |0> (r=$r_squeeze)")

# ---------------------------------------------------------
# Plot Formatting
# ---------------------------------------------------------
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) # Confidently constrain the Y-axis so infinities don't compress the graph

PyPlot.xlabel(L"Laser Exposure Time [Displacement $\alpha$] ($\mu$s)", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Squeezed Fock Metrology", fontsize=14)

# Put legend in the lower left so it doesn't cover the data curves
PyPlot.legend(bbox_to_anchor=(1.05, 0.5), loc="center left")
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
# ---------------------------------------------------------
# QCRB Simulation Loop: Squeezed vs Vacuum
# ---------------------------------------------------------
t_max = 3.0
time_steps = 0.01:0.05:t_max 
states = 0:1 
ψ_ion = normalize(ion["g"] - ion["e"])
d_alpha = 0.01

fig = figure(figsize=(8, 6))
qcrb_matrix = zeros(Float64, length(states), length(time_steps))

# Pre-build the signal operator once to save loop time
sim_mode = zmodes(trap)[1]
D_signal = IonSim.displace(sim_mode, im * d_alpha)
I_spin = identityoperator(ion["g"].basis)
D_system = I_spin ⊗ D_signal

# Squeezing parameter
r_squeeze = 0.5

for (i, n) in enumerate(states)
    qcrb_values = Float64[]
    
    if n == 0
        println("Simulating Ordinary Vacuum |0⟩...")
        ψ_mode = fockstate(sim_mode, 0)
        label_sim = "Simulated Vacuum |0⟩"
        color_sim = "tab:blue"
    else
        println("Simulating Squeezed Vacuum (r = $r_squeeze)...")
        # 1. Trick QuantumOptics into calculating the matrix
        temp_fock_basis = FockBasis(sim_mode.N)
        
        # 2. Squeeze in momentum (anti-squeeze in position)
        z = r_squeeze * exp(1im * pi) 
        S_fock = squeeze(temp_fock_basis, z) 
        
        # 3. Wrap it back into IonSim
        squeeze_op = DenseOperator(sim_mode, sim_mode, S_fock.data)
        vac = fockstate(sim_mode, 0)
        ψ_mode = squeeze_op * vac
        
        label_sim = "Simulated Squeezed |0⟩ (r=$r_squeeze)"
        color_sim = "tab:purple"
    end
    
    ψ_initial = ψ_ion ⊗ ψ_mode
    
    # APPLY SIGNAL FIRST: Create the perturbed initial state
    ψ_initial_perturbed = D_system * ψ_initial
    
    for (j, t) in enumerate(time_steps)
        # 1. Base Trajectory (No Signal)
        sol1 = protocol(ψ_initial, 1, t)
        ancilla_base = ptrace(sol1, 2) 
        
        # 2. Perturbed Trajectory (Signal happened before SDF readout)
        sol2 = protocol(ψ_initial_perturbed, 1, t)
        ancilla_perturbed = ptrace(sol2, 2)
        
        # 3. Calculate true Ancilla QCRB
        qfi, qcrb = calculate_qcrb(ancilla_base, ancilla_perturbed, d_alpha)
        push!(qcrb_values, qcrb)
        
        qcrb_matrix[i, j] = qcrb
        println("Beta: ", round(t, digits=2), " μs, State: ", n==0 ? "Vacuum" : "Squeezed", ", QCRB: ", qcrb)
    end
    
    # Plot simulation as scatter dots
    PyPlot.plot(time_steps, qcrb_values, "o", color=color_sim, markersize=7, label=label_sim)
end

# ---------------------------------------------------------
# Analytical Theory Overlay
# ---------------------------------------------------------
# High-resolution X-axis to capture smooth curves
alphas_theory = range(0.01, stop=t_max, length=1000)

# 1. Theory for Ordinary Vacuum (r = 0)
# Formula: exp(4x^2) / (16x^2)
qcrb_theory_0 = @. exp(4 * alphas_theory^2) / (16 * alphas_theory^2 + 1e-15)

# 2. Theory for Squeezed Vacuum
# Because we used a phase of pi, the wavepacket is anti-squeezed (wider) in the X direction.
# This suppresses the wavepacket separation penalty by e^(-2r).
suppression_factor = exp(-2 * r_squeeze)
qcrb_theory_sq = @. exp(4 * alphas_theory^2 * suppression_factor) / (16 * alphas_theory^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_0, "--", color="black", linewidth=2, label="Theory Vacuum")
PyPlot.plot(alphas_theory, qcrb_theory_sq, ":", color="red", linewidth=2.5, label="Theory Squeezed (r=$r_squeeze)")

# ---------------------------------------------------------
# Plot Formatting
# ---------------------------------------------------------
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) # Confidently constrain the Y-axis so infinities don't compress the graph

PyPlot.xlabel("Laser Exposure Time [Displacement α] (μs)", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Squeezed Metrology", fontsize=14)

# Put legend in the lower right so it doesn't cover the upper-left curves
PyPlot.legend(loc="lower right", fontsize=11)
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Simulating Ordinary Vacuum |0⟩...
# Beta: 0.01 μs, State: Vacuum, QCRB: 631.2804651034652
# Beta: 0.06 μs, State: Vacuum, QCRB: 17.853317960472243
# Beta: 0.11 μs, State: Vacuum, QCRB: 5.480696619445355
# Beta: 0.16 μs, State: Vacuum, QCRB: 2.7366460232628054
# Beta: 0.21 μs, State: Vacuum, QCRB: 1.7067531376906622
# Beta: 0.26 μs, State: Vacuum, QCRB: 1.2222911786859958
# Beta: 0.31 μs, State: Vacuum, QCRB: 0.9620008158741804
# Beta: 0.36 μs, State: Vacuum, QCRB: 0.8140242674113498
# Beta: 0.41 μs, State: Vacuum, QCRB: 0.730716001992581
# Beta: 0.46 μs, State: Vacuum, QCRB: 0.689116207868187
# Beta: 0.51 μs, State: Vacuum, QCRB: 0.6789473672891637
# Beta: 0.56 μs, State: Vacuum, QCRB: 0.695545159072008
# Beta: 0.61 μs, State: Vacuum, QCRB: 0.7385048533548646
# Beta: 0.66 μs, State: Vacuum, QCRB: 0.8106020910282363
# Beta: 0.71 μs, State: Vacuum, QCRB: 0.9183011534542179
# Beta: 0.76 μs, State: Vacuum, QCRB: 1.071108067235525
# Beta: 0.81 μs, State: Vacuum, QCRB: 1.2863343910699536
# Beta: 0.86 μs, State: Vacuum, QCRB: 1.586894629072432
# Beta: 0.91 μs, State: Vacuum, QCRB: 2.011107225018214
# Beta: 0.96 μs, State: Vacuum, QCRB: 2.6163705142388256
# Beta: 1.01 μs, State: Vacuum, QCRB: 3.4879377979552673
# Beta: 1.06 μs, State: Vacuum, QCRB: 4.772931679569251
# Beta: 1.11 μs, State: Vacuum, QCRB: 6.683163802659482
# Beta: 1.16 μs, State: Vacuum, QCRB: 9.596310642984157
# Beta: 1.21 μs, State: Vacuum, QCRB: 14.102597773148151
# Beta: 1.26 μs, State: Vacuum, QCRB: 21.20713981083698
# Beta: 1.31 μs, State: Vacuum, QCRB: 32.680490350766675
# Beta: 1.36 μs, State: Vacuum, QCRB: 51.43305148401149
# Beta: 1.41 μs, State: Vacuum, QCRB: 82.97179047311695
# Beta: 1.46 μs, State: Vacuum, QCRB: 136.7046244690053
# Beta: 1.51 μs, State: Vacuum, QCRB: 230.46838010018095
# Beta: 1.56 μs, State: Vacuum, QCRB: 397.58949876268565
# Beta: 1.61 μs, State: Vacuum, QCRB: 700.0309268303181
# Beta: 1.66 μs, State: Vacuum, QCRB: 1263.2660983918395
# Beta: 1.71 μs, State: Vacuum, QCRB: 2324.366006920716
# Beta: 1.76 μs, State: Vacuum, QCRB: 4378.678227576759
# Beta: 1.81 μs, State: Vacuum, QCRB: 8424.432352216914
# Beta: 1.86 μs, State: Vacuum, QCRB: 16587.222295477415
# Beta: 1.91 μs, State: Vacuum, QCRB: 33452.61584877973
# Beta: 1.96 μs, State: Vacuum, QCRB: 68972.7304583573
# Beta: 2.01 μs, State: Vacuum, QCRB: 144802.29973943587
# Beta: 2.06 μs, State: Vacuum, QCRB: 309775.4400893608
# Beta: 2.11 μs, State: Vacuum, QCRB: 667989.2774536465
# Beta: 2.16 μs, State: Vacuum, QCRB: 1.4328076039132325e6
# Beta: 2.21 μs, State: Vacuum, QCRB: 2.904609677622951e6
# Beta: 2.26 μs, State: Vacuum, QCRB: 4.873156701297271e6
# Beta: 2.31 μs, State: Vacuum, QCRB: 6.143049984481658e6
# Beta: 2.36 μs, State: Vacuum, QCRB: 5.406437201220295e6
# Beta: 2.41 μs, State: Vacuum, QCRB: 3.209889464287818e6
# Beta: 2.46 μs, State: Vacuum, QCRB: 1.4657404575413635e6
# Beta: 2.51 μs, State: Vacuum, QCRB: 635355.6662547193
# Beta: 2.56 μs, State: Vacuum, QCRB: 269515.6087771634
# Beta: 2.61 μs, State: Vacuum, QCRB: 116930.67361737265
# Beta: 2.66 μs, State: Vacuum, QCRB: 51982.5283543898
# Beta: 2.71 μs, State: Vacuum, QCRB: 23756.26295324513
# Beta: 2.76 μs, State: Vacuum, QCRB: 11134.515637505117
# Beta: 2.81 μs, State: Vacuum, QCRB: 5388.939200056294
# Beta: 2.86 μs, State: Vacuum, QCRB: 2677.5135815511967
# Beta: 2.91 μs, State: Vacuum, QCRB: 1375.155431524366
# Beta: 2.96 μs, State: Vacuum, QCRB: 722.8324334930675
# Simulating Squeezed Vacuum (r = 0.5)...
# Beta: 0.01 μs, State: Squeezed, QCRB: 631.1414310771867
# Beta: 0.06 μs, State: Squeezed, QCRB: 17.685195513230923
# Beta: 0.11 μs, State: Squeezed, QCRB: 5.3200712584180545
# Beta: 0.16 μs, State: Squeezed, QCRB: 2.5686514903629236
# Beta: 0.21 μs, State: Squeezed, QCRB: 1.5297509415103465
# Beta: 0.26 μs, State: Squeezed, QCRB: 1.0328704814193848
# Beta: 0.31 μs, State: Squeezed, QCRB: 0.7571938557716789
# Beta: 0.36 μs, State: Squeezed, QCRB: 0.5892831345862728
# Beta: 0.41 μs, State: Squeezed, QCRB: 0.4806637994432055
# Beta: 0.46 μs, State: Squeezed, QCRB: 0.40661449699217206
# Beta: 0.51 μs, State: Squeezed, QCRB: 0.35505091086802154
# Beta: 0.56 μs, State: Squeezed, QCRB: 0.31822483108206756
# Beta: 0.61 μs, State: Squeezed, QCRB: 0.2920473300928232
# Beta: 0.66 μs, State: Squeezed, QCRB: 0.27364798625528686
# Beta: 0.71 μs, State: Squeezed, QCRB: 0.2611837993558186
# Beta: 0.76 μs, State: Squeezed, QCRB: 0.25366062928784816
# Beta: 0.81 μs, State: Squeezed, QCRB: 0.25028795223955674
# Beta: 0.86 μs, State: Squeezed, QCRB: 0.2507015280822846
# Beta: 0.91 μs, State: Squeezed, QCRB: 0.25464171649689077
# Beta: 0.96 μs, State: Squeezed, QCRB: 0.26214096614136834
# Beta: 1.01 μs, State: Squeezed, QCRB: 0.27329839717901244
# Beta: 1.06 μs, State: Squeezed, QCRB: 0.288504623301468
# Beta: 1.11 μs, State: Squeezed, QCRB: 0.3081081297945678
# Beta: 1.16 μs, State: Squeezed, QCRB: 0.33290215593393885
# Beta: 1.21 μs, State: Squeezed, QCRB: 0.3636882133908586
# Beta: 1.26 μs, State: Squeezed, QCRB: 0.4016785322442381
# Beta: 1.31 μs, State: Squeezed, QCRB: 0.44859477781675067
# Beta: 1.36 μs, State: Squeezed, QCRB: 0.5061477180166359
# Beta: 1.41 μs, State: Squeezed, QCRB: 0.5775206119613641
# Beta: 1.46 μs, State: Squeezed, QCRB: 0.6658044141999987
# Beta: 1.51 μs, State: Squeezed, QCRB: 0.7761291304806076
# Beta: 1.56 μs, State: Squeezed, QCRB: 0.9151296295839018
# Beta: 1.61 μs, State: Squeezed, QCRB: 1.0911876396479325
# Beta: 1.66 μs, State: Squeezed, QCRB: 1.318493992779978
# Beta: 1.71 μs, State: Squeezed, QCRB: 1.6135418958740453
# Beta: 1.76 μs, State: Squeezed, QCRB: 2.0058025307809944
# Beta: 1.81 μs, State: Squeezed, QCRB: 2.536307577804512
# Beta: 1.86 μs, State: Squeezed, QCRB: 3.272062524929583
# Beta: 1.91 μs, State: Squeezed, QCRB: 4.331013896760714
# Beta: 1.96 μs, State: Squeezed, QCRB: 5.9085152094388835
# Beta: 2.01 μs, State: Squeezed, QCRB: 8.414969233265781
# Beta: 2.06 μs, State: Squeezed, QCRB: 12.684637991499168
# Beta: 2.11 μs, State: Squeezed, QCRB: 20.821749482681376
# Beta: 2.16 μs, State: Squeezed, QCRB: 39.14053226615808
# Beta: 2.21 μs, State: Squeezed, QCRB: 92.32902938788078
# Beta: 2.26 μs, State: Squeezed, QCRB: 300.43851120965996
# Beta: 2.31 μs, State: Squeezed, QCRB: 344.88270048081966
# Beta: 2.36 μs, State: Squeezed, QCRB: 104.72128833787804
# Beta: 2.41 μs, State: Squeezed, QCRB: 42.48620242149246
# Beta: 2.46 μs, State: Squeezed, QCRB: 22.066458903224067
# Beta: 2.51 μs, State: Squeezed, QCRB: 13.202169679008756
# Beta: 2.56 μs, State: Squeezed, QCRB: 8.657387253159733
# Beta: 2.61 μs, State: Squeezed, QCRB: 6.022526054847225
# Beta: 2.66 μs, State: Squeezed, QCRB: 4.380015542016162
# Beta: 2.71 μs, State: Squeezed, QCRB: 3.290861566457177
# Beta: 2.76 μs, State: Squeezed, QCRB: 2.5360196306567735
# Beta: 2.81 μs, State: Squeezed, QCRB: 1.9977777250947542
# Beta: 2.86 μs, State: Squeezed, QCRB: 1.600483180193222
# Beta: 2.91 μs, State: Squeezed, QCRB: 1.3035094011170794
# Beta: 2.96 μs, State: Squeezed, QCRB: 1.07605957948401
# Figure(PyObject <Figure size 800x600 with 1 Axes>)

# %%
PyPlot.clf()
t_max = 3.0
alphas_theory = range(0.01, stop=t_max, length=1000)

x_norm = @. 4 * alphas_theory^2
qcrb_theory_1 = @. exp(x_norm) / (16 * alphas_theory^2 + 1e-15)

# 2. Theory for Squeezed Fock |1⟩
# Squeezing stretches both the envelope AND the Laguerre ripples by exp(-2r)
# Let x_sq = 4 * α^2 * exp(-2r). The formula is exp(x_sq) / (16α^2 * (1 - x_sq)^2)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
qcrb_theory_sq_0 = @. exp(x_sq) / (16 * alphas_theory^2+ 1e-15)

# 1. Theory for Ordinary Fock |1⟩
# Let x = 4 * α^2. The formula is exp(x) / (16α^2 * (1 - x)^2)
x_norm = @. 4 * alphas_theory^2
qcrb_theory_1 = @. exp(x_norm) / (16 * alphas_theory^2 * (1 - x_norm)^2 + 1e-15)

# 2. Theory for Squeezed Fock |1⟩
# Squeezing stretches both the envelope AND the Laguerre ripples by exp(-2r)
# Let x_sq = 4 * α^2 * exp(-2r). The formula is exp(x_sq) / (16α^2 * (1 - x_sq)^2)
suppression_factor = exp(-2 * r_squeeze)
x_sq = @. 4 * alphas_theory^2 * suppression_factor
qcrb_theory_sq = @. exp(x_sq) / (16 * alphas_theory^2 * (1 - x_sq)^2 + 1e-15)

# Plot the pure analytical equations
PyPlot.plot(alphas_theory, qcrb_theory_1, "--", color="black", linewidth=2, label="Theory Ordinary |1⟩")
PyPlot.plot(alphas_theory, qcrb_theory_sq, ":", color="red", linewidth=2.5, label="Theory Squeezed |1⟩ (r=$r_squeeze)")

PyPlot.plot(alphas_theory, qcrb_theory_0, "--", color="blue", linewidth=2, label="Theory Ordinary |0⟩")
PyPlot.plot(alphas_theory, qcrb_theory_sq_0, ":", color="purple", linewidth=2.5, label="Theory Squeezed |0> (r=$r_squeeze)")

# ---------------------------------------------------------
# Plot Formatting
# ---------------------------------------------------------
PyPlot.yscale("log")
PyPlot.ylim(1e-1, 2e3) # Confidently constrain the Y-axis so infinities don't compress the graph

PyPlot.xlabel(L"Laser Exposure Time [Displacement $\alpha$] ($\mu$s)", fontsize=12)
PyPlot.ylabel("QCRB (Ancilla Measurement Limit)", fontsize=12)
PyPlot.title("Simulation vs Theory: Squeezed Fock Metrology", fontsize=14)

# Put legend in the lower left so it doesn't cover the data curves
PyPlot.legend(bbox_to_anchor=(1.05, 0.5), loc="center left")
PyPlot.grid(which="major", color="gray", alpha=0.3, linestyle="-")
PyPlot.grid(which="minor", color="gray", alpha=0.1, linestyle=":")

display(fig)
# Out:
# Figure(PyObject <Figure size 800x600 with 1 Axes>)
